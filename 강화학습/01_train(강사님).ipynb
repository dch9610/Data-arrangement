# %%
import tensorflow.compat.v1 as tf
import numpy as np
import random
import math
import os

tf.compat.v1.disable_eager_execution()

# %%
# 학습에 필요한 설정값을 정의한다.

epsilon = 1                 		# epsilon-Greedy 기법에 사용할 최초의 epsilon값
epsilonMinimumValue = 0.001 		# epsilon의 최소값 (이 값 이하로 Decay하지 않습니다)
num_actions = 3               	# 에이전트가 취할 수 있는 행동의 개수 - (좌로 움직이기, 가만히 있기, 우로 움직이기)
num_epochs = 2000 					    # 학습에 사용할 반복횟수
hidden_size = 128 					    # 히든레이어의 노드 개수
maxMemory = 500 					      # Replay Memory의 크기
batch_size = 50 					      # 학습에 사용할 배치 개수
gridSize = 10 						      # 에이전트가 플레이하는 게임 화면 크기 (10x10 grid)
state_size = gridSize * gridSize 	# 게임 환경의 현재상태 (10x10 grid)
discount = 0.9 						        # Discount Factor \gamma
learning_rate = 0.2					      # 러닝 레이트

# %%
# 시작과 끝값을 기준으로 랜덤값을 추출하는 함수를 정의한다.
def randf(s, e):
  return (float(random.randrange(0, (e - s) * 9999)) / 10000) + s;

# %%
# DQN 모델을 정의합니다.
# 100(현재 상태 - 10x10 Grid) -> 128 -> 128 -> 3(예측된 각 행동의 Q값)
def build_DQN(x):
  W1 = tf.Variable(tf.truncated_normal(shape=[state_size, hidden_size], stddev=1.0 / math.sqrt(float(state_size))))
  b1 = tf.Variable(tf.truncated_normal(shape=[hidden_size], stddev=0.01))  
  H1_output = tf.nn.relu(tf.matmul(x, W1) + b1)
  W2 = tf.Variable(tf.truncated_normal(shape=[hidden_size, hidden_size],stddev=1.0 / math.sqrt(float(hidden_size))))
  b2 = tf.Variable(tf.truncated_normal(shape=[hidden_size], stddev=0.01))
  H2_output = tf.nn.relu(tf.matmul(H1_output, W2) + b2)
  W3 = tf.Variable(tf.truncated_normal(shape=[hidden_size, num_actions],stddev=1.0 / math.sqrt(float(hidden_size))))
  b3 = tf.Variable(tf.truncated_normal(shape=[num_actions], stddev=0.01))
  output_layer = tf.matmul(H2_output, W3) + b3

  return tf.squeeze(output_layer)

# %%
# 인풋 화면 이미지와 타겟 Q값을 받기 위한 플레이스 홀더를 선언합니다.
x = tf.placeholder(tf.float32, shape=[None, state_size])
y = tf.placeholder(tf.float32, shape=[None, num_actions])

# %%
# DQN 모델을 선언하고 예측결과를 리턴받습니다.
y_pred = build_DQN(x)

# %%
# MSE 손실 함수와 옵티마이저를 정의합니다.
loss = tf.reduce_sum(tf.square(y-y_pred)) / (2*batch_size)  # MSE 손실 함수
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

# %%
# CatchGame을 수행하는 Environment를 구현합니다.
class CatchEnvironment():
  # 상태의 초기값을 지정합니다.
  def __init__(self, gridSize):
    self.gridSize = gridSize
    self.state_size = self.gridSize * self.gridSize
    self.state = np.empty(3, dtype = np.uint8) 

  # 관찰 결과를 리턴합니다.
  def observe(self):
    canvas = self.drawState()
    canvas = np.reshape(canvas, (-1,self.state_size))
    return canvas

  # 현재 상태(fruit, basket)를 화면에 출력합니다.
  def drawState(self):
    canvas = np.zeros((self.gridSize, self.gridSize))
    # fruit를 화면에 그립니다.
    canvas[self.state[0]-1, self.state[1]-1] = 1  
    # basket을 화면에 그립니다. 
    canvas[self.gridSize-1, self.state[2] -1 - 1] = 1
    canvas[self.gridSize-1, self.state[2] -1] = 1
    canvas[self.gridSize-1, self.state[2] -1 + 1] = 1    
    return canvas        

  # 게임을 초기 상태로 리셋합니다.
  def reset(self): 
    initialFruitColumn = random.randrange(1, self.gridSize + 1)
    initialBucketPosition = random.randrange(2, self.gridSize + 1 - 1)
    self.state = np.array([1, initialFruitColumn, initialBucketPosition]) 
    return self.getState()

  # 현재 상태를 불러옵니다.
  def getState(self):
    stateInfo = self.state
    fruit_row = stateInfo[0]
    fruit_col = stateInfo[1]
    basket = stateInfo[2]
    return fruit_row, fruit_col, basket

  # 에이전트가 취한 행동에 대한 보상을 줍니다.
  def getReward(self):
    fruitRow, fruitColumn, basket = self.getState()
    # 만약 fruit가 바닥에 닿았을 때
    if (fruitRow == self.gridSize - 1):  
      # basket이 fruit을 받아내면 1의 reward를 줍니다.
      if (abs(fruitColumn - basket) <= 1): 
        return 1
      # fruit를 받아내지 못하면 -1의 reward를 줍니다.
      else:
        return -1
    # fruit가 바닥에 닿지 않은 중립적인 상태는 0의 reward를 줍니다.
    else:
      return 0

  # 게임이 끝났는지를 체크합니다.(fruit가 바닥에 닿으면 한게임이 종료됩니다.)
  def isGameOver(self):
    if (self.state[0] == self.gridSize - 1): 
      return True 
    else: 
      return False 

  # action(좌로 한칸 이동, 제자리, 우로 한칸이동)에 따라 basket의 위치를 업데이트합니다.
  def updateState(self, action):
    move = 0
    if (action == 0):
      move = -1
    elif (action == 1):
      move = 0
    elif (action == 2):
      move = 1
    fruitRow, fruitColumn, basket = self.getState()
    newBasket = min(max(2, basket + move), self.gridSize - 1) # min/max는 basket이 grid밖으로 벗어나는것을 방지합니다.
    fruitRow = fruitRow + 1  # fruit는 매 행동을 취할때마다 1칸씩 아래로 떨어집니다. 
    self.state = np.array([fruitRow, fruitColumn, newBasket])

  # 행동을 취합니다. 0 : 왼쪽으로 이동, 1 : 가만히 있기, 2 : 오른쪽으로 이동
  def act(self, action):
    self.updateState(action)
    reward = self.getReward()
    gameOver = self.isGameOver()
    return self.observe(), reward, gameOver, self.getState()

# %%
# Replay Memory를 class로 정의합니다.
class ReplayMemory:
  def __init__(self, gridSize, maxMemory, discount):
    self.maxMemory = maxMemory
    self.gridSize = gridSize
    self.state_size = self.gridSize * self.gridSize
    self.discount = discount
    canvas = np.zeros((self.gridSize, self.gridSize))
    canvas = np.reshape(canvas, (-1,self.state_size))
    self.inputState = np.empty((self.maxMemory, 100), dtype = np.float32)
    self.actions = np.zeros(self.maxMemory, dtype = np.uint8)
    self.nextState = np.empty((self.maxMemory, 100), dtype = np.float32)
    self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
    self.rewards = np.empty(self.maxMemory, dtype = np.int8) 
    self.count = 0
    self.current = 0

  # 경험을 Replay Memory에 저장합니다.
  def remember(self, currentState, action, reward, nextState, gameOver):
    self.actions[self.current] = action
    self.rewards[self.current] = reward
    self.inputState[self.current, ...] = currentState
    self.nextState[self.current, ...] = nextState
    self.gameOver[self.current] = gameOver
    self.count = max(self.count, self.current + 1)
    self.current = (self.current + 1) % self.maxMemory

  def getBatch(self, y_pred, batch_size, num_actions, state_size, sess, X):
    # 취할 수 있는 가장 큰 배치 사이즈를 선택합니다. (학습 초기에는 batch_size만큼의 기억이 없습니다.)
    memoryLength = self.count
    chosenBatchSize = min(batch_size, memoryLength)

    # 인풋 데이터와 타겟데이터를 선언합니다. 
    inputs = np.zeros((chosenBatchSize, state_size))
    targets = np.zeros((chosenBatchSize, num_actions))

    # 배치안의 값을 설정합니다.
    for i in range(chosenBatchSize):
      # 배치에 포함될 기억을 랜덤으로 선택합니다.
      randomIndex = random.randrange(0, memoryLength)
      # 현재 상태와 Q값을 불러옵니다.
      current_inputState = np.reshape(self.inputState[randomIndex], (1, 100))
      target = sess.run(y_pred, feed_dict={X: current_inputState})
      
      # 현재 상태 바로 다음 상태를 불러오고 다음 상태에서 취할수 있는 가장 큰 Q값을 계산합니다.
      current_nextState = np.reshape(self.nextState[randomIndex], (1, 100))
      nextStateQ = sess.run(y_pred, feed_dict={X: current_nextState})      
      nextStateMaxQ = np.amax(nextStateQ)
      # 만약 게임오버라면 reward로 Q값을 업데이트하고 
      if (self.gameOver[randomIndex] == True):
        target[self.actions[randomIndex]] = self.rewards[randomIndex]
      # 게임오버가 아니라면 타겟 Q값(최적의 Q값)을 아래 수식을 이용해서 계산합니다.
      # Q* = reward + discount(gamma) * max_a' Q(s',a')
      else:
        target[self.actions[randomIndex]] = self.rewards[randomIndex] + self.discount * nextStateMaxQ

      # 인풋과 타겟 데이터에 값을 지정합니다.
      inputs[i] = current_inputState
      targets[i] = target

    return inputs, targets

# %%
# 학습을 진행하는 main 함수를 정의합니다.
def main(_):
  print("트레이닝을 시작합니다.")

  # 게임 플레이 환경을 선언합니다.
  env = CatchEnvironment(gridSize)

  # Replay Memory를 선언합니다.
  memory = ReplayMemory(gridSize, maxMemory, discount)

  # 학습된 파라미터를 저장하기 위한 tf.train.Saver를 선언합니다.
  saver = tf.train.Saver()
  
  winCount = 0
  with tf.Session() as sess:   
    # 변수들의 초기값을 할당합니다.
    sess.run(tf.global_variables_initializer())

    for i in range(num_epochs+1):
      # 환경을 초기화합니다.
      err = 0
      env.reset()
     
      isGameOver = False

      # 최초의 상태를 불러옵니다.
      currentState = env.observe()
            
      while (isGameOver != True):
        action = -9999  # Q값을 초기화합니다.
        # epsilon-Greedy 기법에 따라 랜덤한 행동을 할지 최적의 행동을 할지를 결정합니다.
        global epsilon
        if (randf(0, 1) <= epsilon):
          # epsilon 확률만큼 랜덤한 행동을 합니다.
          action = random.randrange(0, num_actions)
        else:          
          # (1-epsilon) 확률만큼 최적의 행동을 합니다.
          # 현재 상태를 DQN의 인풋으로 넣어서 예측된 최적의 Q(s,a)값들을 리턴받습니다.
          q = sess.run(y_pred, feed_dict={x: currentState})   
          # Q(s,a)가 가장 높은 행동을 선택합니다.
          action = q.argmax()

        # epsilon값을 0.9999만큼 Decay합니다.
        if (epsilon > epsilonMinimumValue):
          epsilon = epsilon * 0.999
        
        # 에이전트가 행동을 하고 다음 보상과 다음 상태에 대한 정보를 리턴 받습니다.
        nextState, reward, gameOver, stateInfo = env.act(action)
            
        # 만약 과일을 제대로 받아냈다면 승리 횟수를 1 올립니다.
        if (reward == 1):
          winCount = winCount + 1

        # 에이전트가 수집한 정보를 Replay Memory에 저장합니다.
        memory.remember(currentState, action, reward, nextState, gameOver)
        
        # 현재 상태를 다음 상태로 업데이트하고 GameOver유무를 체크합니다.
        currentState = nextState
        isGameOver = gameOver
                
        # Replay Memory로부터 학습에 사용할 Batch 데이터를 불러옵니다.
        inputs, targets = memory.getBatch(y_pred, batch_size, num_actions, state_size, sess, x)
        
        # 최적화를 수행하고 손실함수를 리턴받습니다.
        _, loss_print = sess.run([optimizer, loss], feed_dict={x: inputs, y: targets})  
        err = err + loss_print

      print("반복(Epoch): %d, 에러(err): %.4f, 승리횟수(Win count): %d, 승리비율(Win ratio): %.4f" % (i, err, winCount, float(winCount)/float(i+1)*100))
    # 학습이 모두 끝나면 파라미터를 지정된 경로에 저장합니다.
    print("트레이닝 완료")
    save_path = saver.save(sess, os.getcwd()+"/model.ckpt")
    print("%s 경로에 파라미터가 저장되었습니다" % save_path)

# %%
if __name__ == '__main__':
  # main 함수를 호출합니다.
  tf.app.run()
# Out:
# 트레이닝을 시작합니다.
# 반복(Epoch): 0, 에러(err): 0.0410, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 1, 에러(err): 0.0600, 승리횟수(Win count): 1, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 2, 에러(err): 0.2094, 승리횟수(Win count): 2, 승리비율(Win ratio): 66.6667
# 반복(Epoch): 3, 에러(err): 0.2332, 승리횟수(Win count): 2, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 4, 에러(err): 0.3235, 승리횟수(Win count): 2, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 5, 에러(err): 0.3279, 승리횟수(Win count): 2, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 6, 에러(err): 0.3857, 승리횟수(Win count): 3, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 7, 에러(err): 0.3825, 승리횟수(Win count): 3, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 8, 에러(err): 0.4670, 승리횟수(Win count): 4, 승리비율(Win ratio): 44.4444
# 반복(Epoch): 9, 에러(err): 0.4345, 승리횟수(Win count): 4, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 10, 에러(err): 0.3747, 승리횟수(Win count): 4, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 11, 에러(err): 0.3997, 승리횟수(Win count): 4, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 12, 에러(err): 0.4478, 승리횟수(Win count): 4, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 13, 에러(err): 0.5542, 승리횟수(Win count): 5, 승리비율(Win ratio): 35.7143
# 반복(Epoch): 14, 에러(err): 0.3985, 승리횟수(Win count): 5, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 15, 에러(err): 0.4630, 승리횟수(Win count): 5, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 16, 에러(err): 0.5419, 승리횟수(Win count): 5, 승리비율(Win ratio): 29.4118
# 반복(Epoch): 17, 에러(err): 0.4542, 승리횟수(Win count): 5, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 18, 에러(err): 0.3469, 승리횟수(Win count): 6, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 19, 에러(err): 0.3653, 승리횟수(Win count): 6, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 20, 에러(err): 0.4086, 승리횟수(Win count): 7, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 21, 에러(err): 0.3647, 승리횟수(Win count): 7, 승리비율(Win ratio): 31.8182
# 반복(Epoch): 22, 에러(err): 0.3100, 승리횟수(Win count): 7, 승리비율(Win ratio): 30.4348
# 반복(Epoch): 23, 에러(err): 0.4813, 승리횟수(Win count): 8, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 24, 에러(err): 0.4108, 승리횟수(Win count): 8, 승리비율(Win ratio): 32.0000
# 반복(Epoch): 25, 에러(err): 0.4526, 승리횟수(Win count): 8, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 26, 에러(err): 0.4044, 승리횟수(Win count): 8, 승리비율(Win ratio): 29.6296
# 반복(Epoch): 27, 에러(err): 0.3501, 승리횟수(Win count): 8, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 28, 에러(err): 0.4822, 승리횟수(Win count): 9, 승리비율(Win ratio): 31.0345
# 반복(Epoch): 29, 에러(err): 0.4629, 승리횟수(Win count): 9, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 30, 에러(err): 0.4160, 승리횟수(Win count): 10, 승리비율(Win ratio): 32.2581
# 반복(Epoch): 31, 에러(err): 0.4118, 승리횟수(Win count): 11, 승리비율(Win ratio): 34.3750
# 반복(Epoch): 32, 에러(err): 0.3938, 승리횟수(Win count): 11, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 33, 에러(err): 0.3740, 승리횟수(Win count): 11, 승리비율(Win ratio): 32.3529
# 반복(Epoch): 34, 에러(err): 0.4671, 승리횟수(Win count): 12, 승리비율(Win ratio): 34.2857
# 반복(Epoch): 35, 에러(err): 0.3815, 승리횟수(Win count): 12, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 36, 에러(err): 0.3800, 승리횟수(Win count): 12, 승리비율(Win ratio): 32.4324
# 반복(Epoch): 37, 에러(err): 0.3853, 승리횟수(Win count): 12, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 38, 에러(err): 0.3477, 승리횟수(Win count): 12, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 39, 에러(err): 0.4287, 승리횟수(Win count): 12, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 40, 에러(err): 0.3007, 승리횟수(Win count): 12, 승리비율(Win ratio): 29.2683
# 반복(Epoch): 41, 에러(err): 0.4448, 승리횟수(Win count): 13, 승리비율(Win ratio): 30.9524
# 반복(Epoch): 42, 에러(err): 0.3300, 승리횟수(Win count): 13, 승리비율(Win ratio): 30.2326
# 반복(Epoch): 43, 에러(err): 0.3171, 승리횟수(Win count): 13, 승리비율(Win ratio): 29.5455
# 반복(Epoch): 44, 에러(err): 0.3107, 승리횟수(Win count): 13, 승리비율(Win ratio): 28.8889
# 반복(Epoch): 45, 에러(err): 0.3775, 승리횟수(Win count): 13, 승리비율(Win ratio): 28.2609
# 반복(Epoch): 46, 에러(err): 0.3657, 승리횟수(Win count): 13, 승리비율(Win ratio): 27.6596
# 반복(Epoch): 47, 에러(err): 0.3876, 승리횟수(Win count): 13, 승리비율(Win ratio): 27.0833
# 반복(Epoch): 48, 에러(err): 0.3027, 승리횟수(Win count): 14, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 49, 에러(err): 0.3424, 승리횟수(Win count): 14, 승리비율(Win ratio): 28.0000
# 반복(Epoch): 50, 에러(err): 0.3283, 승리횟수(Win count): 14, 승리비율(Win ratio): 27.4510
# 반복(Epoch): 51, 에러(err): 0.2921, 승리횟수(Win count): 14, 승리비율(Win ratio): 26.9231
# 반복(Epoch): 52, 에러(err): 0.3847, 승리횟수(Win count): 14, 승리비율(Win ratio): 26.4151
# 반복(Epoch): 53, 에러(err): 0.3637, 승리횟수(Win count): 15, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 54, 에러(err): 0.2893, 승리횟수(Win count): 15, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 55, 에러(err): 0.2436, 승리횟수(Win count): 15, 승리비율(Win ratio): 26.7857
# 반복(Epoch): 56, 에러(err): 0.3159, 승리횟수(Win count): 15, 승리비율(Win ratio): 26.3158
# 반복(Epoch): 57, 에러(err): 0.2980, 승리횟수(Win count): 15, 승리비율(Win ratio): 25.8621
# 반복(Epoch): 58, 에러(err): 0.3105, 승리횟수(Win count): 16, 승리비율(Win ratio): 27.1186
# 반복(Epoch): 59, 에러(err): 0.2540, 승리횟수(Win count): 16, 승리비율(Win ratio): 26.6667
# 반복(Epoch): 60, 에러(err): 0.3405, 승리횟수(Win count): 16, 승리비율(Win ratio): 26.2295
# 반복(Epoch): 61, 에러(err): 0.3507, 승리횟수(Win count): 16, 승리비율(Win ratio): 25.8065
# 반복(Epoch): 62, 에러(err): 0.3235, 승리횟수(Win count): 16, 승리비율(Win ratio): 25.3968
# 반복(Epoch): 63, 에러(err): 0.2741, 승리횟수(Win count): 17, 승리비율(Win ratio): 26.5625
# 반복(Epoch): 64, 에러(err): 0.2965, 승리횟수(Win count): 17, 승리비율(Win ratio): 26.1538
# 반복(Epoch): 65, 에러(err): 0.2901, 승리횟수(Win count): 18, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 66, 에러(err): 0.2458, 승리횟수(Win count): 18, 승리비율(Win ratio): 26.8657
# 반복(Epoch): 67, 에러(err): 0.3323, 승리횟수(Win count): 19, 승리비율(Win ratio): 27.9412
# 반복(Epoch): 68, 에러(err): 0.2488, 승리횟수(Win count): 19, 승리비율(Win ratio): 27.5362
# 반복(Epoch): 69, 에러(err): 0.2775, 승리횟수(Win count): 20, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 70, 에러(err): 0.2442, 승리횟수(Win count): 20, 승리비율(Win ratio): 28.1690
# 반복(Epoch): 71, 에러(err): 0.2880, 승리횟수(Win count): 20, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 72, 에러(err): 0.3351, 승리횟수(Win count): 20, 승리비율(Win ratio): 27.3973
# 반복(Epoch): 73, 에러(err): 0.2901, 승리횟수(Win count): 21, 승리비율(Win ratio): 28.3784
# 반복(Epoch): 74, 에러(err): 0.2701, 승리횟수(Win count): 21, 승리비율(Win ratio): 28.0000
# 반복(Epoch): 75, 에러(err): 0.3189, 승리횟수(Win count): 21, 승리비율(Win ratio): 27.6316
# 반복(Epoch): 76, 에러(err): 0.2118, 승리횟수(Win count): 22, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 77, 에러(err): 0.2841, 승리횟수(Win count): 22, 승리비율(Win ratio): 28.2051
# 반복(Epoch): 78, 에러(err): 0.2689, 승리횟수(Win count): 22, 승리비율(Win ratio): 27.8481
# 반복(Epoch): 79, 에러(err): 0.2750, 승리횟수(Win count): 22, 승리비율(Win ratio): 27.5000
# 반복(Epoch): 80, 에러(err): 0.2489, 승리횟수(Win count): 23, 승리비율(Win ratio): 28.3951
# 반복(Epoch): 81, 에러(err): 0.2262, 승리횟수(Win count): 23, 승리비율(Win ratio): 28.0488
# 반복(Epoch): 82, 에러(err): 0.3051, 승리횟수(Win count): 23, 승리비율(Win ratio): 27.7108
# 반복(Epoch): 83, 에러(err): 0.2098, 승리횟수(Win count): 23, 승리비율(Win ratio): 27.3810
# 반복(Epoch): 84, 에러(err): 0.1826, 승리횟수(Win count): 23, 승리비율(Win ratio): 27.0588
# 반복(Epoch): 85, 에러(err): 0.2128, 승리횟수(Win count): 24, 승리비율(Win ratio): 27.9070
# 반복(Epoch): 86, 에러(err): 0.2556, 승리횟수(Win count): 24, 승리비율(Win ratio): 27.5862
# 반복(Epoch): 87, 에러(err): 0.2721, 승리횟수(Win count): 24, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 88, 에러(err): 0.2621, 승리횟수(Win count): 24, 승리비율(Win ratio): 26.9663
# 반복(Epoch): 89, 에러(err): 0.2407, 승리횟수(Win count): 24, 승리비율(Win ratio): 26.6667
# 반복(Epoch): 90, 에러(err): 0.2052, 승리횟수(Win count): 24, 승리비율(Win ratio): 26.3736
# 반복(Epoch): 91, 에러(err): 0.2562, 승리횟수(Win count): 25, 승리비율(Win ratio): 27.1739
# 반복(Epoch): 92, 에러(err): 0.2035, 승리횟수(Win count): 25, 승리비율(Win ratio): 26.8817
# 반복(Epoch): 93, 에러(err): 0.2089, 승리횟수(Win count): 25, 승리비율(Win ratio): 26.5957
# 반복(Epoch): 94, 에러(err): 0.2163, 승리횟수(Win count): 25, 승리비율(Win ratio): 26.3158
# 반복(Epoch): 95, 에러(err): 0.2131, 승리횟수(Win count): 26, 승리비율(Win ratio): 27.0833
# 반복(Epoch): 96, 에러(err): 0.2866, 승리횟수(Win count): 26, 승리비율(Win ratio): 26.8041
# 반복(Epoch): 97, 에러(err): 0.2648, 승리횟수(Win count): 26, 승리비율(Win ratio): 26.5306
# 반복(Epoch): 98, 에러(err): 0.2485, 승리횟수(Win count): 27, 승리비율(Win ratio): 27.2727
# 반복(Epoch): 99, 에러(err): 0.2239, 승리횟수(Win count): 27, 승리비율(Win ratio): 27.0000
# 반복(Epoch): 100, 에러(err): 0.1932, 승리횟수(Win count): 28, 승리비율(Win ratio): 27.7228
# 반복(Epoch): 101, 에러(err): 0.2876, 승리횟수(Win count): 28, 승리비율(Win ratio): 27.4510
# 반복(Epoch): 102, 에러(err): 0.2450, 승리횟수(Win count): 28, 승리비율(Win ratio): 27.1845
# 반복(Epoch): 103, 에러(err): 0.2188, 승리횟수(Win count): 29, 승리비율(Win ratio): 27.8846
# 반복(Epoch): 104, 에러(err): 0.2593, 승리횟수(Win count): 29, 승리비율(Win ratio): 27.6190
# 반복(Epoch): 105, 에러(err): 0.2807, 승리횟수(Win count): 30, 승리비율(Win ratio): 28.3019
# 반복(Epoch): 106, 에러(err): 0.2598, 승리횟수(Win count): 30, 승리비율(Win ratio): 28.0374
# 반복(Epoch): 107, 에러(err): 0.2318, 승리횟수(Win count): 30, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 108, 에러(err): 0.2442, 승리횟수(Win count): 31, 승리비율(Win ratio): 28.4404
# 반복(Epoch): 109, 에러(err): 0.2723, 승리횟수(Win count): 31, 승리비율(Win ratio): 28.1818
# 반복(Epoch): 110, 에러(err): 0.2554, 승리횟수(Win count): 32, 승리비율(Win ratio): 28.8288
# 반복(Epoch): 111, 에러(err): 0.2675, 승리횟수(Win count): 32, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 112, 에러(err): 0.2604, 승리횟수(Win count): 32, 승리비율(Win ratio): 28.3186
# 반복(Epoch): 113, 에러(err): 0.2183, 승리횟수(Win count): 32, 승리비율(Win ratio): 28.0702
# 반복(Epoch): 114, 에러(err): 0.2105, 승리횟수(Win count): 32, 승리비율(Win ratio): 27.8261
# 반복(Epoch): 115, 에러(err): 0.2453, 승리횟수(Win count): 33, 승리비율(Win ratio): 28.4483
# 반복(Epoch): 116, 에러(err): 0.1998, 승리횟수(Win count): 33, 승리비율(Win ratio): 28.2051
# 반복(Epoch): 117, 에러(err): 0.1994, 승리횟수(Win count): 34, 승리비율(Win ratio): 28.8136
# 반복(Epoch): 118, 에러(err): 0.1766, 승리횟수(Win count): 34, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 119, 에러(err): 0.2036, 승리횟수(Win count): 35, 승리비율(Win ratio): 29.1667
# 반복(Epoch): 120, 에러(err): 0.2118, 승리횟수(Win count): 35, 승리비율(Win ratio): 28.9256
# 반복(Epoch): 121, 에러(err): 0.2237, 승리횟수(Win count): 35, 승리비율(Win ratio): 28.6885
# 반복(Epoch): 122, 에러(err): 0.2424, 승리횟수(Win count): 35, 승리비율(Win ratio): 28.4553
# 반복(Epoch): 123, 에러(err): 0.1906, 승리횟수(Win count): 35, 승리비율(Win ratio): 28.2258
# 반복(Epoch): 124, 에러(err): 0.1922, 승리횟수(Win count): 35, 승리비율(Win ratio): 28.0000
# 반복(Epoch): 125, 에러(err): 0.2246, 승리횟수(Win count): 35, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 126, 에러(err): 0.1614, 승리횟수(Win count): 36, 승리비율(Win ratio): 28.3465
# 반복(Epoch): 127, 에러(err): 0.2438, 승리횟수(Win count): 36, 승리비율(Win ratio): 28.1250
# 반복(Epoch): 128, 에러(err): 0.1764, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.9070
# 반복(Epoch): 129, 에러(err): 0.2863, 승리횟수(Win count): 36, 승리비율(Win ratio): 27.6923
# 반복(Epoch): 130, 에러(err): 0.2150, 승리횟수(Win count): 37, 승리비율(Win ratio): 28.2443
# 반복(Epoch): 131, 에러(err): 0.2028, 승리횟수(Win count): 37, 승리비율(Win ratio): 28.0303
# 반복(Epoch): 132, 에러(err): 0.2135, 승리횟수(Win count): 38, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 133, 에러(err): 0.1715, 승리횟수(Win count): 38, 승리비율(Win ratio): 28.3582
# 반복(Epoch): 134, 에러(err): 0.2217, 승리횟수(Win count): 38, 승리비율(Win ratio): 28.1481
# 반복(Epoch): 135, 에러(err): 0.2260, 승리횟수(Win count): 38, 승리비율(Win ratio): 27.9412
# 반복(Epoch): 136, 에러(err): 0.1530, 승리횟수(Win count): 38, 승리비율(Win ratio): 27.7372
# 반복(Epoch): 137, 에러(err): 0.1442, 승리횟수(Win count): 38, 승리비율(Win ratio): 27.5362
# 반복(Epoch): 138, 에러(err): 0.1392, 승리횟수(Win count): 39, 승리비율(Win ratio): 28.0576
# 반복(Epoch): 139, 에러(err): 0.1881, 승리횟수(Win count): 39, 승리비율(Win ratio): 27.8571
# 반복(Epoch): 140, 에러(err): 0.1877, 승리횟수(Win count): 40, 승리비율(Win ratio): 28.3688
# 반복(Epoch): 141, 에러(err): 0.1893, 승리횟수(Win count): 40, 승리비율(Win ratio): 28.1690
# 반복(Epoch): 142, 에러(err): 0.2105, 승리횟수(Win count): 41, 승리비율(Win ratio): 28.6713
# 반복(Epoch): 143, 에러(err): 0.1412, 승리횟수(Win count): 42, 승리비율(Win ratio): 29.1667
# 반복(Epoch): 144, 에러(err): 0.1466, 승리횟수(Win count): 43, 승리비율(Win ratio): 29.6552
# 반복(Epoch): 145, 에러(err): 0.1390, 승리횟수(Win count): 43, 승리비율(Win ratio): 29.4521
# 반복(Epoch): 146, 에러(err): 0.2354, 승리횟수(Win count): 44, 승리비율(Win ratio): 29.9320
# 반복(Epoch): 147, 에러(err): 0.1688, 승리횟수(Win count): 44, 승리비율(Win ratio): 29.7297
# 반복(Epoch): 148, 에러(err): 0.1959, 승리횟수(Win count): 44, 승리비율(Win ratio): 29.5302
# 반복(Epoch): 149, 에러(err): 0.2615, 승리횟수(Win count): 44, 승리비율(Win ratio): 29.3333
# 반복(Epoch): 150, 에러(err): 0.2487, 승리횟수(Win count): 45, 승리비율(Win ratio): 29.8013
# 반복(Epoch): 151, 에러(err): 0.1652, 승리횟수(Win count): 46, 승리비율(Win ratio): 30.2632
# 반복(Epoch): 152, 에러(err): 0.2242, 승리횟수(Win count): 47, 승리비율(Win ratio): 30.7190
# 반복(Epoch): 153, 에러(err): 0.1622, 승리횟수(Win count): 48, 승리비율(Win ratio): 31.1688
# 반복(Epoch): 154, 에러(err): 0.2567, 승리횟수(Win count): 49, 승리비율(Win ratio): 31.6129
# 반복(Epoch): 155, 에러(err): 0.2000, 승리횟수(Win count): 50, 승리비율(Win ratio): 32.0513
# 반복(Epoch): 156, 에러(err): 0.2223, 승리횟수(Win count): 51, 승리비율(Win ratio): 32.4841
# 반복(Epoch): 157, 에러(err): 0.1508, 승리횟수(Win count): 52, 승리비율(Win ratio): 32.9114
# 반복(Epoch): 158, 에러(err): 0.1867, 승리횟수(Win count): 52, 승리비율(Win ratio): 32.7044
# 반복(Epoch): 159, 에러(err): 0.1751, 승리횟수(Win count): 52, 승리비율(Win ratio): 32.5000
# 반복(Epoch): 160, 에러(err): 0.1529, 승리횟수(Win count): 52, 승리비율(Win ratio): 32.2981
# 반복(Epoch): 161, 에러(err): 0.1451, 승리횟수(Win count): 53, 승리비율(Win ratio): 32.7160
# 반복(Epoch): 162, 에러(err): 0.1757, 승리횟수(Win count): 53, 승리비율(Win ratio): 32.5153
# 반복(Epoch): 163, 에러(err): 0.1905, 승리횟수(Win count): 53, 승리비율(Win ratio): 32.3171
# 반복(Epoch): 164, 에러(err): 0.1639, 승리횟수(Win count): 53, 승리비율(Win ratio): 32.1212
# 반복(Epoch): 165, 에러(err): 0.1534, 승리횟수(Win count): 54, 승리비율(Win ratio): 32.5301
# 반복(Epoch): 166, 에러(err): 0.1392, 승리횟수(Win count): 55, 승리비율(Win ratio): 32.9341
# 반복(Epoch): 167, 에러(err): 0.1654, 승리횟수(Win count): 56, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 168, 에러(err): 0.1325, 승리횟수(Win count): 56, 승리비율(Win ratio): 33.1361
# 반복(Epoch): 169, 에러(err): 0.1201, 승리횟수(Win count): 57, 승리비율(Win ratio): 33.5294
# 반복(Epoch): 170, 에러(err): 0.1288, 승리횟수(Win count): 58, 승리비율(Win ratio): 33.9181
# 반복(Epoch): 171, 에러(err): 0.1717, 승리횟수(Win count): 59, 승리비율(Win ratio): 34.3023
# 반복(Epoch): 172, 에러(err): 0.1442, 승리횟수(Win count): 60, 승리비율(Win ratio): 34.6821
# 반복(Epoch): 173, 에러(err): 0.1197, 승리횟수(Win count): 60, 승리비율(Win ratio): 34.4828
# 반복(Epoch): 174, 에러(err): 0.1740, 승리횟수(Win count): 61, 승리비율(Win ratio): 34.8571
# 반복(Epoch): 175, 에러(err): 0.1666, 승리횟수(Win count): 62, 승리비율(Win ratio): 35.2273
# 반복(Epoch): 176, 에러(err): 0.1506, 승리횟수(Win count): 63, 승리비율(Win ratio): 35.5932
# 반복(Epoch): 177, 에러(err): 0.1453, 승리횟수(Win count): 64, 승리비율(Win ratio): 35.9551
# 반복(Epoch): 178, 에러(err): 0.1454, 승리횟수(Win count): 64, 승리비율(Win ratio): 35.7542
# 반복(Epoch): 179, 에러(err): 0.1273, 승리횟수(Win count): 65, 승리비율(Win ratio): 36.1111
# 반복(Epoch): 180, 에러(err): 0.1154, 승리횟수(Win count): 66, 승리비율(Win ratio): 36.4641
# 반복(Epoch): 181, 에러(err): 0.1328, 승리횟수(Win count): 67, 승리비율(Win ratio): 36.8132
# 반복(Epoch): 182, 에러(err): 0.1451, 승리횟수(Win count): 68, 승리비율(Win ratio): 37.1585
# 반복(Epoch): 183, 에러(err): 0.1346, 승리횟수(Win count): 69, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 184, 에러(err): 0.1279, 승리횟수(Win count): 69, 승리비율(Win ratio): 37.2973
# 반복(Epoch): 185, 에러(err): 0.1273, 승리횟수(Win count): 70, 승리비율(Win ratio): 37.6344
# 반복(Epoch): 186, 에러(err): 0.1042, 승리횟수(Win count): 70, 승리비율(Win ratio): 37.4332
# 반복(Epoch): 187, 에러(err): 0.1568, 승리횟수(Win count): 70, 승리비율(Win ratio): 37.2340
# 반복(Epoch): 188, 에러(err): 0.1368, 승리횟수(Win count): 70, 승리비율(Win ratio): 37.0370
# 반복(Epoch): 189, 에러(err): 0.0900, 승리횟수(Win count): 71, 승리비율(Win ratio): 37.3684
# 반복(Epoch): 190, 에러(err): 0.1014, 승리횟수(Win count): 72, 승리비율(Win ratio): 37.6963
# 반복(Epoch): 191, 에러(err): 0.1018, 승리횟수(Win count): 73, 승리비율(Win ratio): 38.0208
# 반복(Epoch): 192, 에러(err): 0.1333, 승리횟수(Win count): 73, 승리비율(Win ratio): 37.8238
# 반복(Epoch): 193, 에러(err): 0.1321, 승리횟수(Win count): 74, 승리비율(Win ratio): 38.1443
# 반복(Epoch): 194, 에러(err): 0.1586, 승리횟수(Win count): 75, 승리비율(Win ratio): 38.4615
# 반복(Epoch): 195, 에러(err): 0.1574, 승리횟수(Win count): 75, 승리비율(Win ratio): 38.2653
# 반복(Epoch): 196, 에러(err): 0.1345, 승리횟수(Win count): 76, 승리비율(Win ratio): 38.5787
# 반복(Epoch): 197, 에러(err): 0.1517, 승리횟수(Win count): 76, 승리비율(Win ratio): 38.3838
# 반복(Epoch): 198, 에러(err): 0.0883, 승리횟수(Win count): 76, 승리비율(Win ratio): 38.1910
# 반복(Epoch): 199, 에러(err): 0.0952, 승리횟수(Win count): 77, 승리비율(Win ratio): 38.5000
# 반복(Epoch): 200, 에러(err): 0.1058, 승리횟수(Win count): 77, 승리비율(Win ratio): 38.3085
# 반복(Epoch): 201, 에러(err): 0.0991, 승리횟수(Win count): 77, 승리비율(Win ratio): 38.1188
# 반복(Epoch): 202, 에러(err): 0.1277, 승리횟수(Win count): 77, 승리비율(Win ratio): 37.9310
# 반복(Epoch): 203, 에러(err): 0.1463, 승리횟수(Win count): 77, 승리비율(Win ratio): 37.7451
# 반복(Epoch): 204, 에러(err): 0.1170, 승리횟수(Win count): 78, 승리비율(Win ratio): 38.0488
# 반복(Epoch): 205, 에러(err): 0.1276, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.8641
# 반복(Epoch): 206, 에러(err): 0.1925, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.6812
# 반복(Epoch): 207, 에러(err): 0.1522, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 208, 에러(err): 0.1277, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.3206
# 반복(Epoch): 209, 에러(err): 0.1789, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.1429
# 반복(Epoch): 210, 에러(err): 0.1181, 승리횟수(Win count): 79, 승리비율(Win ratio): 37.4408
# 반복(Epoch): 211, 에러(err): 0.1632, 승리횟수(Win count): 80, 승리비율(Win ratio): 37.7358
# 반복(Epoch): 212, 에러(err): 0.1433, 승리횟수(Win count): 81, 승리비율(Win ratio): 38.0282
# 반복(Epoch): 213, 에러(err): 0.1820, 승리횟수(Win count): 81, 승리비율(Win ratio): 37.8505
# 반복(Epoch): 214, 에러(err): 0.1771, 승리횟수(Win count): 82, 승리비율(Win ratio): 38.1395
# 반복(Epoch): 215, 에러(err): 0.1330, 승리횟수(Win count): 83, 승리비율(Win ratio): 38.4259
# 반복(Epoch): 216, 에러(err): 0.1017, 승리횟수(Win count): 83, 승리비율(Win ratio): 38.2488
# 반복(Epoch): 217, 에러(err): 0.1300, 승리횟수(Win count): 84, 승리비율(Win ratio): 38.5321
# 반복(Epoch): 218, 에러(err): 0.1159, 승리횟수(Win count): 85, 승리비율(Win ratio): 38.8128
# 반복(Epoch): 219, 에러(err): 0.1439, 승리횟수(Win count): 85, 승리비율(Win ratio): 38.6364
# 반복(Epoch): 220, 에러(err): 0.1155, 승리횟수(Win count): 86, 승리비율(Win ratio): 38.9140
# 반복(Epoch): 221, 에러(err): 0.1319, 승리횟수(Win count): 87, 승리비율(Win ratio): 39.1892
# 반복(Epoch): 222, 에러(err): 0.1761, 승리횟수(Win count): 87, 승리비율(Win ratio): 39.0135
# 반복(Epoch): 223, 에러(err): 0.1226, 승리횟수(Win count): 87, 승리비율(Win ratio): 38.8393
# 반복(Epoch): 224, 에러(err): 0.0925, 승리횟수(Win count): 88, 승리비율(Win ratio): 39.1111
# 반복(Epoch): 225, 에러(err): 0.0759, 승리횟수(Win count): 89, 승리비율(Win ratio): 39.3805
# 반복(Epoch): 226, 에러(err): 0.1439, 승리횟수(Win count): 89, 승리비율(Win ratio): 39.2070
# 반복(Epoch): 227, 에러(err): 0.1181, 승리횟수(Win count): 90, 승리비율(Win ratio): 39.4737
# 반복(Epoch): 228, 에러(err): 0.1008, 승리횟수(Win count): 91, 승리비율(Win ratio): 39.7380
# 반복(Epoch): 229, 에러(err): 0.1234, 승리횟수(Win count): 91, 승리비율(Win ratio): 39.5652
# 반복(Epoch): 230, 에러(err): 0.1043, 승리횟수(Win count): 91, 승리비율(Win ratio): 39.3939
# 반복(Epoch): 231, 에러(err): 0.1135, 승리횟수(Win count): 92, 승리비율(Win ratio): 39.6552
# 반복(Epoch): 232, 에러(err): 0.1103, 승리횟수(Win count): 93, 승리비율(Win ratio): 39.9142
# 반복(Epoch): 233, 에러(err): 0.1071, 승리횟수(Win count): 94, 승리비율(Win ratio): 40.1709
# 반복(Epoch): 234, 에러(err): 0.0888, 승리횟수(Win count): 95, 승리비율(Win ratio): 40.4255
# 반복(Epoch): 235, 에러(err): 0.1240, 승리횟수(Win count): 95, 승리비율(Win ratio): 40.2542
# 반복(Epoch): 236, 에러(err): 0.1305, 승리횟수(Win count): 95, 승리비율(Win ratio): 40.0844
# 반복(Epoch): 237, 에러(err): 0.1648, 승리횟수(Win count): 95, 승리비율(Win ratio): 39.9160
# 반복(Epoch): 238, 에러(err): 0.1017, 승리횟수(Win count): 96, 승리비율(Win ratio): 40.1674
# 반복(Epoch): 239, 에러(err): 0.0894, 승리횟수(Win count): 96, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 240, 에러(err): 0.1063, 승리횟수(Win count): 96, 승리비율(Win ratio): 39.8340
# 반복(Epoch): 241, 에러(err): 0.0906, 승리횟수(Win count): 96, 승리비율(Win ratio): 39.6694
# 반복(Epoch): 242, 에러(err): 0.1170, 승리횟수(Win count): 97, 승리비율(Win ratio): 39.9177
# 반복(Epoch): 243, 에러(err): 0.1006, 승리횟수(Win count): 97, 승리비율(Win ratio): 39.7541
# 반복(Epoch): 244, 에러(err): 0.0851, 승리횟수(Win count): 98, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 245, 에러(err): 0.0837, 승리횟수(Win count): 98, 승리비율(Win ratio): 39.8374
# 반복(Epoch): 246, 에러(err): 0.1036, 승리횟수(Win count): 98, 승리비율(Win ratio): 39.6761
# 반복(Epoch): 247, 에러(err): 0.1103, 승리횟수(Win count): 98, 승리비율(Win ratio): 39.5161
# 반복(Epoch): 248, 에러(err): 0.0849, 승리횟수(Win count): 98, 승리비율(Win ratio): 39.3574
# 반복(Epoch): 249, 에러(err): 0.0866, 승리횟수(Win count): 98, 승리비율(Win ratio): 39.2000
# 반복(Epoch): 250, 에러(err): 0.0872, 승리횟수(Win count): 98, 승리비율(Win ratio): 39.0438
# 반복(Epoch): 251, 에러(err): 0.1191, 승리횟수(Win count): 99, 승리비율(Win ratio): 39.2857
# 반복(Epoch): 252, 에러(err): 0.0863, 승리횟수(Win count): 100, 승리비율(Win ratio): 39.5257
# 반복(Epoch): 253, 에러(err): 0.0861, 승리횟수(Win count): 100, 승리비율(Win ratio): 39.3701
# 반복(Epoch): 254, 에러(err): 0.0759, 승리횟수(Win count): 101, 승리비율(Win ratio): 39.6078
# 반복(Epoch): 255, 에러(err): 0.0902, 승리횟수(Win count): 101, 승리비율(Win ratio): 39.4531
# 반복(Epoch): 256, 에러(err): 0.0720, 승리횟수(Win count): 102, 승리비율(Win ratio): 39.6887
# 반복(Epoch): 257, 에러(err): 0.0749, 승리횟수(Win count): 103, 승리비율(Win ratio): 39.9225
# 반복(Epoch): 258, 에러(err): 0.0834, 승리횟수(Win count): 103, 승리비율(Win ratio): 39.7683
# 반복(Epoch): 259, 에러(err): 0.1090, 승리횟수(Win count): 103, 승리비율(Win ratio): 39.6154
# 반복(Epoch): 260, 에러(err): 0.1318, 승리횟수(Win count): 104, 승리비율(Win ratio): 39.8467
# 반복(Epoch): 261, 에러(err): 0.1781, 승리횟수(Win count): 105, 승리비율(Win ratio): 40.0763
# 반복(Epoch): 262, 에러(err): 0.1005, 승리횟수(Win count): 106, 승리비율(Win ratio): 40.3042
# 반복(Epoch): 263, 에러(err): 0.1127, 승리횟수(Win count): 106, 승리비율(Win ratio): 40.1515
# 반복(Epoch): 264, 에러(err): 0.1410, 승리횟수(Win count): 106, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 265, 에러(err): 0.1001, 승리횟수(Win count): 106, 승리비율(Win ratio): 39.8496
# 반복(Epoch): 266, 에러(err): 0.1190, 승리횟수(Win count): 107, 승리비율(Win ratio): 40.0749
# 반복(Epoch): 267, 에러(err): 0.1131, 승리횟수(Win count): 108, 승리비율(Win ratio): 40.2985
# 반복(Epoch): 268, 에러(err): 0.1126, 승리횟수(Win count): 108, 승리비율(Win ratio): 40.1487
# 반복(Epoch): 269, 에러(err): 0.0872, 승리횟수(Win count): 109, 승리비율(Win ratio): 40.3704
# 반복(Epoch): 270, 에러(err): 0.0762, 승리횟수(Win count): 109, 승리비율(Win ratio): 40.2214
# 반복(Epoch): 271, 에러(err): 0.0786, 승리횟수(Win count): 109, 승리비율(Win ratio): 40.0735
# 반복(Epoch): 272, 에러(err): 0.0996, 승리횟수(Win count): 110, 승리비율(Win ratio): 40.2930
# 반복(Epoch): 273, 에러(err): 0.0831, 승리횟수(Win count): 111, 승리비율(Win ratio): 40.5109
# 반복(Epoch): 274, 에러(err): 0.0822, 승리횟수(Win count): 111, 승리비율(Win ratio): 40.3636
# 반복(Epoch): 275, 에러(err): 0.0865, 승리횟수(Win count): 111, 승리비율(Win ratio): 40.2174
# 반복(Epoch): 276, 에러(err): 0.0814, 승리횟수(Win count): 112, 승리비율(Win ratio): 40.4332
# 반복(Epoch): 277, 에러(err): 0.0779, 승리횟수(Win count): 112, 승리비율(Win ratio): 40.2878
# 반복(Epoch): 278, 에러(err): 0.1061, 승리횟수(Win count): 113, 승리비율(Win ratio): 40.5018
# 반복(Epoch): 279, 에러(err): 0.0794, 승리횟수(Win count): 113, 승리비율(Win ratio): 40.3571
# 반복(Epoch): 280, 에러(err): 0.0749, 승리횟수(Win count): 114, 승리비율(Win ratio): 40.5694
# 반복(Epoch): 281, 에러(err): 0.1235, 승리횟수(Win count): 114, 승리비율(Win ratio): 40.4255
# 반복(Epoch): 282, 에러(err): 0.0878, 승리횟수(Win count): 115, 승리비율(Win ratio): 40.6360
# 반복(Epoch): 283, 에러(err): 0.1239, 승리횟수(Win count): 116, 승리비율(Win ratio): 40.8451
# 반복(Epoch): 284, 에러(err): 0.1210, 승리횟수(Win count): 117, 승리비율(Win ratio): 41.0526
# 반복(Epoch): 285, 에러(err): 0.0992, 승리횟수(Win count): 118, 승리비율(Win ratio): 41.2587
# 반복(Epoch): 286, 에러(err): 0.0963, 승리횟수(Win count): 119, 승리비율(Win ratio): 41.4634
# 반복(Epoch): 287, 에러(err): 0.0896, 승리횟수(Win count): 120, 승리비율(Win ratio): 41.6667
# 반복(Epoch): 288, 에러(err): 0.0779, 승리횟수(Win count): 121, 승리비율(Win ratio): 41.8685
# 반복(Epoch): 289, 에러(err): 0.0533, 승리횟수(Win count): 122, 승리비율(Win ratio): 42.0690
# 반복(Epoch): 290, 에러(err): 0.0728, 승리횟수(Win count): 122, 승리비율(Win ratio): 41.9244
# 반복(Epoch): 291, 에러(err): 0.0693, 승리횟수(Win count): 123, 승리비율(Win ratio): 42.1233
# 반복(Epoch): 292, 에러(err): 0.0557, 승리횟수(Win count): 123, 승리비율(Win ratio): 41.9795
# 반복(Epoch): 293, 에러(err): 0.0675, 승리횟수(Win count): 124, 승리비율(Win ratio): 42.1769
# 반복(Epoch): 294, 에러(err): 0.0708, 승리횟수(Win count): 125, 승리비율(Win ratio): 42.3729
# 반복(Epoch): 295, 에러(err): 0.0698, 승리횟수(Win count): 125, 승리비율(Win ratio): 42.2297
# 반복(Epoch): 296, 에러(err): 0.0573, 승리횟수(Win count): 126, 승리비율(Win ratio): 42.4242
# 반복(Epoch): 297, 에러(err): 0.0762, 승리횟수(Win count): 127, 승리비율(Win ratio): 42.6174
# 반복(Epoch): 298, 에러(err): 0.0744, 승리횟수(Win count): 127, 승리비율(Win ratio): 42.4749
# 반복(Epoch): 299, 에러(err): 0.0755, 승리횟수(Win count): 127, 승리비율(Win ratio): 42.3333
# 반복(Epoch): 300, 에러(err): 0.1103, 승리횟수(Win count): 128, 승리비율(Win ratio): 42.5249
# 반복(Epoch): 301, 에러(err): 0.0765, 승리횟수(Win count): 129, 승리비율(Win ratio): 42.7152
# 반복(Epoch): 302, 에러(err): 0.0878, 승리횟수(Win count): 130, 승리비율(Win ratio): 42.9043
# 반복(Epoch): 303, 에러(err): 0.0650, 승리횟수(Win count): 131, 승리비율(Win ratio): 43.0921
# 반복(Epoch): 304, 에러(err): 0.0780, 승리횟수(Win count): 132, 승리비율(Win ratio): 43.2787
# 반복(Epoch): 305, 에러(err): 0.0996, 승리횟수(Win count): 132, 승리비율(Win ratio): 43.1373
# 반복(Epoch): 306, 에러(err): 0.0811, 승리횟수(Win count): 133, 승리비율(Win ratio): 43.3225
# 반복(Epoch): 307, 에러(err): 0.0715, 승리횟수(Win count): 134, 승리비율(Win ratio): 43.5065
# 반복(Epoch): 308, 에러(err): 0.0920, 승리횟수(Win count): 135, 승리비율(Win ratio): 43.6893
# 반복(Epoch): 309, 에러(err): 0.0721, 승리횟수(Win count): 136, 승리비율(Win ratio): 43.8710
# 반복(Epoch): 310, 에러(err): 0.0841, 승리횟수(Win count): 136, 승리비율(Win ratio): 43.7299
# 반복(Epoch): 311, 에러(err): 0.0618, 승리횟수(Win count): 137, 승리비율(Win ratio): 43.9103
# 반복(Epoch): 312, 에러(err): 0.0742, 승리횟수(Win count): 138, 승리비율(Win ratio): 44.0895
# 반복(Epoch): 313, 에러(err): 0.1143, 승리횟수(Win count): 139, 승리비율(Win ratio): 44.2675
# 반복(Epoch): 314, 에러(err): 0.0906, 승리횟수(Win count): 140, 승리비율(Win ratio): 44.4444
# 반복(Epoch): 315, 에러(err): 0.0564, 승리횟수(Win count): 141, 승리비율(Win ratio): 44.6203
# 반복(Epoch): 316, 에러(err): 0.0715, 승리횟수(Win count): 141, 승리비율(Win ratio): 44.4795
# 반복(Epoch): 317, 에러(err): 0.0551, 승리횟수(Win count): 142, 승리비율(Win ratio): 44.6541
# 반복(Epoch): 318, 에러(err): 0.0874, 승리횟수(Win count): 143, 승리비율(Win ratio): 44.8276
# 반복(Epoch): 319, 에러(err): 0.1059, 승리횟수(Win count): 144, 승리비율(Win ratio): 45.0000
# 반복(Epoch): 320, 에러(err): 0.1104, 승리횟수(Win count): 145, 승리비율(Win ratio): 45.1713
# 반복(Epoch): 321, 에러(err): 0.1009, 승리횟수(Win count): 145, 승리비율(Win ratio): 45.0311
# 반복(Epoch): 322, 에러(err): 0.0613, 승리횟수(Win count): 146, 승리비율(Win ratio): 45.2012
# 반복(Epoch): 323, 에러(err): 0.1569, 승리횟수(Win count): 147, 승리비율(Win ratio): 45.3704
# 반복(Epoch): 324, 에러(err): 0.0918, 승리횟수(Win count): 148, 승리비율(Win ratio): 45.5385
# 반복(Epoch): 325, 에러(err): 0.0968, 승리횟수(Win count): 149, 승리비율(Win ratio): 45.7055
# 반복(Epoch): 326, 에러(err): 0.0784, 승리횟수(Win count): 150, 승리비율(Win ratio): 45.8716
# 반복(Epoch): 327, 에러(err): 0.0501, 승리횟수(Win count): 151, 승리비율(Win ratio): 46.0366
# 반복(Epoch): 328, 에러(err): 0.1051, 승리횟수(Win count): 152, 승리비율(Win ratio): 46.2006
# 반복(Epoch): 329, 에러(err): 0.0552, 승리횟수(Win count): 153, 승리비율(Win ratio): 46.3636
# 반복(Epoch): 330, 에러(err): 0.0644, 승리횟수(Win count): 154, 승리비율(Win ratio): 46.5257
# 반복(Epoch): 331, 에러(err): 0.0850, 승리횟수(Win count): 154, 승리비율(Win ratio): 46.3855
# 반복(Epoch): 332, 에러(err): 0.0594, 승리횟수(Win count): 155, 승리비율(Win ratio): 46.5465
# 반복(Epoch): 333, 에러(err): 0.0426, 승리횟수(Win count): 156, 승리비율(Win ratio): 46.7066
# 반복(Epoch): 334, 에러(err): 0.0728, 승리횟수(Win count): 157, 승리비율(Win ratio): 46.8657
# 반복(Epoch): 335, 에러(err): 0.0669, 승리횟수(Win count): 158, 승리비율(Win ratio): 47.0238
# 반복(Epoch): 336, 에러(err): 0.0496, 승리횟수(Win count): 159, 승리비율(Win ratio): 47.1810
# 반복(Epoch): 337, 에러(err): 0.0540, 승리횟수(Win count): 160, 승리비율(Win ratio): 47.3373
# 반복(Epoch): 338, 에러(err): 0.0783, 승리횟수(Win count): 161, 승리비율(Win ratio): 47.4926
# 반복(Epoch): 339, 에러(err): 0.0788, 승리횟수(Win count): 162, 승리비율(Win ratio): 47.6471
# 반복(Epoch): 340, 에러(err): 0.0887, 승리횟수(Win count): 163, 승리비율(Win ratio): 47.8006
# 반복(Epoch): 341, 에러(err): 0.0419, 승리횟수(Win count): 164, 승리비율(Win ratio): 47.9532
# 반복(Epoch): 342, 에러(err): 0.0499, 승리횟수(Win count): 165, 승리비율(Win ratio): 48.1050
# 반복(Epoch): 343, 에러(err): 0.0376, 승리횟수(Win count): 165, 승리비율(Win ratio): 47.9651
# 반복(Epoch): 344, 에러(err): 0.0613, 승리횟수(Win count): 166, 승리비율(Win ratio): 48.1159
# 반복(Epoch): 345, 에러(err): 0.0551, 승리횟수(Win count): 167, 승리비율(Win ratio): 48.2659
# 반복(Epoch): 346, 에러(err): 0.0425, 승리횟수(Win count): 168, 승리비율(Win ratio): 48.4150
# 반복(Epoch): 347, 에러(err): 0.0448, 승리횟수(Win count): 169, 승리비율(Win ratio): 48.5632
# 반복(Epoch): 348, 에러(err): 0.0336, 승리횟수(Win count): 170, 승리비율(Win ratio): 48.7106
# 반복(Epoch): 349, 에러(err): 0.0454, 승리횟수(Win count): 171, 승리비율(Win ratio): 48.8571
# 반복(Epoch): 350, 에러(err): 0.0465, 승리횟수(Win count): 172, 승리비율(Win ratio): 49.0028
# 반복(Epoch): 351, 에러(err): 0.0414, 승리횟수(Win count): 173, 승리비율(Win ratio): 49.1477
# 반복(Epoch): 352, 에러(err): 0.0478, 승리횟수(Win count): 173, 승리비율(Win ratio): 49.0085
# 반복(Epoch): 353, 에러(err): 0.0819, 승리횟수(Win count): 174, 승리비율(Win ratio): 49.1525
# 반복(Epoch): 354, 에러(err): 0.0638, 승리횟수(Win count): 175, 승리비율(Win ratio): 49.2958
# 반복(Epoch): 355, 에러(err): 0.0583, 승리횟수(Win count): 176, 승리비율(Win ratio): 49.4382
# 반복(Epoch): 356, 에러(err): 0.0516, 승리횟수(Win count): 177, 승리비율(Win ratio): 49.5798
# 반복(Epoch): 357, 에러(err): 0.0761, 승리횟수(Win count): 178, 승리비율(Win ratio): 49.7207
# 반복(Epoch): 358, 에러(err): 0.0748, 승리횟수(Win count): 179, 승리비율(Win ratio): 49.8607
# 반복(Epoch): 359, 에러(err): 0.0402, 승리횟수(Win count): 179, 승리비율(Win ratio): 49.7222
# 반복(Epoch): 360, 에러(err): 0.0664, 승리횟수(Win count): 180, 승리비율(Win ratio): 49.8615
# 반복(Epoch): 361, 에러(err): 0.0500, 승리횟수(Win count): 181, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 362, 에러(err): 0.0473, 승리횟수(Win count): 182, 승리비율(Win ratio): 50.1377
# 반복(Epoch): 363, 에러(err): 0.0576, 승리횟수(Win count): 183, 승리비율(Win ratio): 50.2747
# 반복(Epoch): 364, 에러(err): 0.0636, 승리횟수(Win count): 184, 승리비율(Win ratio): 50.4110
# 반복(Epoch): 365, 에러(err): 0.0263, 승리횟수(Win count): 185, 승리비율(Win ratio): 50.5464
# 반복(Epoch): 366, 에러(err): 0.0581, 승리횟수(Win count): 186, 승리비율(Win ratio): 50.6812
# 반복(Epoch): 367, 에러(err): 0.0687, 승리횟수(Win count): 187, 승리비율(Win ratio): 50.8152
# 반복(Epoch): 368, 에러(err): 0.0957, 승리횟수(Win count): 188, 승리비율(Win ratio): 50.9485
# 반복(Epoch): 369, 에러(err): 0.0453, 승리횟수(Win count): 189, 승리비율(Win ratio): 51.0811
# 반복(Epoch): 370, 에러(err): 0.0277, 승리횟수(Win count): 190, 승리비율(Win ratio): 51.2129
# 반복(Epoch): 371, 에러(err): 0.0266, 승리횟수(Win count): 191, 승리비율(Win ratio): 51.3441
# 반복(Epoch): 372, 에러(err): 0.0459, 승리횟수(Win count): 192, 승리비율(Win ratio): 51.4745
# 반복(Epoch): 373, 에러(err): 0.0489, 승리횟수(Win count): 193, 승리비율(Win ratio): 51.6043
# 반복(Epoch): 374, 에러(err): 0.0340, 승리횟수(Win count): 194, 승리비율(Win ratio): 51.7333
# 반복(Epoch): 375, 에러(err): 0.0510, 승리횟수(Win count): 195, 승리비율(Win ratio): 51.8617
# 반복(Epoch): 376, 에러(err): 0.0341, 승리횟수(Win count): 196, 승리비율(Win ratio): 51.9894
# 반복(Epoch): 377, 에러(err): 0.0399, 승리횟수(Win count): 197, 승리비율(Win ratio): 52.1164
# 반복(Epoch): 378, 에러(err): 0.0293, 승리횟수(Win count): 198, 승리비율(Win ratio): 52.2427
# 반복(Epoch): 379, 에러(err): 0.0381, 승리횟수(Win count): 199, 승리비율(Win ratio): 52.3684
# 반복(Epoch): 380, 에러(err): 0.0288, 승리횟수(Win count): 200, 승리비율(Win ratio): 52.4934
# 반복(Epoch): 381, 에러(err): 0.0374, 승리횟수(Win count): 201, 승리비율(Win ratio): 52.6178
# 반복(Epoch): 382, 에러(err): 0.0249, 승리횟수(Win count): 202, 승리비율(Win ratio): 52.7415
# 반복(Epoch): 383, 에러(err): 0.0182, 승리횟수(Win count): 203, 승리비율(Win ratio): 52.8646
# 반복(Epoch): 384, 에러(err): 0.0374, 승리횟수(Win count): 204, 승리비율(Win ratio): 52.9870
# 반복(Epoch): 385, 에러(err): 0.0281, 승리횟수(Win count): 204, 승리비율(Win ratio): 52.8497
# 반복(Epoch): 386, 에러(err): 0.0253, 승리횟수(Win count): 205, 승리비율(Win ratio): 52.9716
# 반복(Epoch): 387, 에러(err): 0.0231, 승리횟수(Win count): 206, 승리비율(Win ratio): 53.0928
# 반복(Epoch): 388, 에러(err): 0.0269, 승리횟수(Win count): 207, 승리비율(Win ratio): 53.2134
# 반복(Epoch): 389, 에러(err): 0.0154, 승리횟수(Win count): 208, 승리비율(Win ratio): 53.3333
# 반복(Epoch): 390, 에러(err): 0.0264, 승리횟수(Win count): 209, 승리비율(Win ratio): 53.4527
# 반복(Epoch): 391, 에러(err): 0.0108, 승리횟수(Win count): 210, 승리비율(Win ratio): 53.5714
# 반복(Epoch): 392, 에러(err): 0.0207, 승리횟수(Win count): 211, 승리비율(Win ratio): 53.6896
# 반복(Epoch): 393, 에러(err): 0.0341, 승리횟수(Win count): 212, 승리비율(Win ratio): 53.8071
# 반복(Epoch): 394, 에러(err): 0.0169, 승리횟수(Win count): 213, 승리비율(Win ratio): 53.9241
# 반복(Epoch): 395, 에러(err): 0.0213, 승리횟수(Win count): 214, 승리비율(Win ratio): 54.0404
# 반복(Epoch): 396, 에러(err): 0.0154, 승리횟수(Win count): 215, 승리비율(Win ratio): 54.1562
# 반복(Epoch): 397, 에러(err): 0.0135, 승리횟수(Win count): 216, 승리비율(Win ratio): 54.2714
# 반복(Epoch): 398, 에러(err): 0.0452, 승리횟수(Win count): 217, 승리비율(Win ratio): 54.3860
# 반복(Epoch): 399, 에러(err): 0.0196, 승리횟수(Win count): 218, 승리비율(Win ratio): 54.5000
# 반복(Epoch): 400, 에러(err): 0.0235, 승리횟수(Win count): 219, 승리비율(Win ratio): 54.6135
# 반복(Epoch): 401, 에러(err): 0.0104, 승리횟수(Win count): 220, 승리비율(Win ratio): 54.7264
# 반복(Epoch): 402, 에러(err): 0.0158, 승리횟수(Win count): 221, 승리비율(Win ratio): 54.8387
# 반복(Epoch): 403, 에러(err): 0.0152, 승리횟수(Win count): 222, 승리비율(Win ratio): 54.9505
# 반복(Epoch): 404, 에러(err): 0.0132, 승리횟수(Win count): 223, 승리비율(Win ratio): 55.0617
# 반복(Epoch): 405, 에러(err): 0.0159, 승리횟수(Win count): 224, 승리비율(Win ratio): 55.1724
# 반복(Epoch): 406, 에러(err): 0.0090, 승리횟수(Win count): 225, 승리비율(Win ratio): 55.2826
# 반복(Epoch): 407, 에러(err): 0.0137, 승리횟수(Win count): 226, 승리비율(Win ratio): 55.3922
# 반복(Epoch): 408, 에러(err): 0.0275, 승리횟수(Win count): 227, 승리비율(Win ratio): 55.5012
# 반복(Epoch): 409, 에러(err): 0.0256, 승리횟수(Win count): 228, 승리비율(Win ratio): 55.6098
# 반복(Epoch): 410, 에러(err): 0.0101, 승리횟수(Win count): 229, 승리비율(Win ratio): 55.7178
# 반복(Epoch): 411, 에러(err): 0.0143, 승리횟수(Win count): 229, 승리비율(Win ratio): 55.5825
# 반복(Epoch): 412, 에러(err): 0.0092, 승리횟수(Win count): 230, 승리비율(Win ratio): 55.6901
# 반복(Epoch): 413, 에러(err): 0.0109, 승리횟수(Win count): 231, 승리비율(Win ratio): 55.7971
# 반복(Epoch): 414, 에러(err): 0.0150, 승리횟수(Win count): 232, 승리비율(Win ratio): 55.9036
# 반복(Epoch): 415, 에러(err): 0.0138, 승리횟수(Win count): 233, 승리비율(Win ratio): 56.0096
# 반복(Epoch): 416, 에러(err): 0.0189, 승리횟수(Win count): 234, 승리비율(Win ratio): 56.1151
# 반복(Epoch): 417, 에러(err): 0.0234, 승리횟수(Win count): 235, 승리비율(Win ratio): 56.2201
# 반복(Epoch): 418, 에러(err): 0.0111, 승리횟수(Win count): 236, 승리비율(Win ratio): 56.3246
# 반복(Epoch): 419, 에러(err): 0.0172, 승리횟수(Win count): 237, 승리비율(Win ratio): 56.4286
# 반복(Epoch): 420, 에러(err): 0.0195, 승리횟수(Win count): 238, 승리비율(Win ratio): 56.5321
# 반복(Epoch): 421, 에러(err): 0.0122, 승리횟수(Win count): 238, 승리비율(Win ratio): 56.3981
# 반복(Epoch): 422, 에러(err): 0.0164, 승리횟수(Win count): 239, 승리비율(Win ratio): 56.5012
# 반복(Epoch): 423, 에러(err): 0.0523, 승리횟수(Win count): 240, 승리비율(Win ratio): 56.6038
# 반복(Epoch): 424, 에러(err): 0.0231, 승리횟수(Win count): 241, 승리비율(Win ratio): 56.7059
# 반복(Epoch): 425, 에러(err): 0.0163, 승리횟수(Win count): 242, 승리비율(Win ratio): 56.8075
# 반복(Epoch): 426, 에러(err): 0.0154, 승리횟수(Win count): 243, 승리비율(Win ratio): 56.9087
# 반복(Epoch): 427, 에러(err): 0.0433, 승리횟수(Win count): 244, 승리비율(Win ratio): 57.0093
# 반복(Epoch): 428, 에러(err): 0.0200, 승리횟수(Win count): 245, 승리비율(Win ratio): 57.1096
# 반복(Epoch): 429, 에러(err): 0.0145, 승리횟수(Win count): 246, 승리비율(Win ratio): 57.2093
# 반복(Epoch): 430, 에러(err): 0.0133, 승리횟수(Win count): 247, 승리비율(Win ratio): 57.3086
# 반복(Epoch): 431, 에러(err): 0.0181, 승리횟수(Win count): 248, 승리비율(Win ratio): 57.4074
# 반복(Epoch): 432, 에러(err): 0.0095, 승리횟수(Win count): 249, 승리비율(Win ratio): 57.5058
# 반복(Epoch): 433, 에러(err): 0.0216, 승리횟수(Win count): 250, 승리비율(Win ratio): 57.6037
# 반복(Epoch): 434, 에러(err): 0.0158, 승리횟수(Win count): 251, 승리비율(Win ratio): 57.7011
# 반복(Epoch): 435, 에러(err): 0.0100, 승리횟수(Win count): 251, 승리비율(Win ratio): 57.5688
# 반복(Epoch): 436, 에러(err): 0.0997, 승리횟수(Win count): 252, 승리비율(Win ratio): 57.6659
# 반복(Epoch): 437, 에러(err): 0.0389, 승리횟수(Win count): 253, 승리비율(Win ratio): 57.7626
# 반복(Epoch): 438, 에러(err): 0.0416, 승리횟수(Win count): 254, 승리비율(Win ratio): 57.8588
# 반복(Epoch): 439, 에러(err): 0.0240, 승리횟수(Win count): 255, 승리비율(Win ratio): 57.9545
# 반복(Epoch): 440, 에러(err): 0.0291, 승리횟수(Win count): 256, 승리비율(Win ratio): 58.0499
# 반복(Epoch): 441, 에러(err): 0.0393, 승리횟수(Win count): 257, 승리비율(Win ratio): 58.1448
# 반복(Epoch): 442, 에러(err): 0.0228, 승리횟수(Win count): 258, 승리비율(Win ratio): 58.2393
# 반복(Epoch): 443, 에러(err): 0.0252, 승리횟수(Win count): 258, 승리비율(Win ratio): 58.1081
# 반복(Epoch): 444, 에러(err): 0.0315, 승리횟수(Win count): 259, 승리비율(Win ratio): 58.2022
# 반복(Epoch): 445, 에러(err): 0.0156, 승리횟수(Win count): 260, 승리비율(Win ratio): 58.2960
# 반복(Epoch): 446, 에러(err): 0.0280, 승리횟수(Win count): 261, 승리비율(Win ratio): 58.3893
# 반복(Epoch): 447, 에러(err): 0.0175, 승리횟수(Win count): 262, 승리비율(Win ratio): 58.4821
# 반복(Epoch): 448, 에러(err): 0.0138, 승리횟수(Win count): 263, 승리비율(Win ratio): 58.5746
# 반복(Epoch): 449, 에러(err): 0.0175, 승리횟수(Win count): 264, 승리비율(Win ratio): 58.6667
# 반복(Epoch): 450, 에러(err): 0.0158, 승리횟수(Win count): 265, 승리비율(Win ratio): 58.7583
# 반복(Epoch): 451, 에러(err): 0.0203, 승리횟수(Win count): 266, 승리비율(Win ratio): 58.8496
# 반복(Epoch): 452, 에러(err): 0.0160, 승리횟수(Win count): 267, 승리비율(Win ratio): 58.9404
# 반복(Epoch): 453, 에러(err): 0.0123, 승리횟수(Win count): 268, 승리비율(Win ratio): 59.0308
# 반복(Epoch): 454, 에러(err): 0.0172, 승리횟수(Win count): 269, 승리비율(Win ratio): 59.1209
# 반복(Epoch): 455, 에러(err): 0.0221, 승리횟수(Win count): 270, 승리비율(Win ratio): 59.2105
# 반복(Epoch): 456, 에러(err): 0.0163, 승리횟수(Win count): 271, 승리비율(Win ratio): 59.2998
# 반복(Epoch): 457, 에러(err): 0.0158, 승리횟수(Win count): 272, 승리비율(Win ratio): 59.3886
# 반복(Epoch): 458, 에러(err): 0.0134, 승리횟수(Win count): 273, 승리비율(Win ratio): 59.4771
# 반복(Epoch): 459, 에러(err): 0.0245, 승리횟수(Win count): 274, 승리비율(Win ratio): 59.5652
# 반복(Epoch): 460, 에러(err): 0.0152, 승리횟수(Win count): 275, 승리비율(Win ratio): 59.6529
# 반복(Epoch): 461, 에러(err): 0.0115, 승리횟수(Win count): 276, 승리비율(Win ratio): 59.7403
# 반복(Epoch): 462, 에러(err): 0.0167, 승리횟수(Win count): 277, 승리비율(Win ratio): 59.8272
# 반복(Epoch): 463, 에러(err): 0.0152, 승리횟수(Win count): 278, 승리비율(Win ratio): 59.9138
# 반복(Epoch): 464, 에러(err): 0.0133, 승리횟수(Win count): 279, 승리비율(Win ratio): 60.0000
# 반복(Epoch): 465, 에러(err): 0.0154, 승리횟수(Win count): 280, 승리비율(Win ratio): 60.0858
# 반복(Epoch): 466, 에러(err): 0.0134, 승리횟수(Win count): 281, 승리비율(Win ratio): 60.1713
# 반복(Epoch): 467, 에러(err): 0.0098, 승리횟수(Win count): 282, 승리비율(Win ratio): 60.2564
# 반복(Epoch): 468, 에러(err): 0.0104, 승리횟수(Win count): 283, 승리비율(Win ratio): 60.3412
# 반복(Epoch): 469, 에러(err): 0.0092, 승리횟수(Win count): 284, 승리비율(Win ratio): 60.4255
# 반복(Epoch): 470, 에러(err): 0.0098, 승리횟수(Win count): 284, 승리비율(Win ratio): 60.2972
# 반복(Epoch): 471, 에러(err): 0.0609, 승리횟수(Win count): 285, 승리비율(Win ratio): 60.3814
# 반복(Epoch): 472, 에러(err): 0.0664, 승리횟수(Win count): 286, 승리비율(Win ratio): 60.4651
# 반복(Epoch): 473, 에러(err): 0.0131, 승리횟수(Win count): 287, 승리비율(Win ratio): 60.5485
# 반복(Epoch): 474, 에러(err): 0.0097, 승리횟수(Win count): 288, 승리비율(Win ratio): 60.6316
# 반복(Epoch): 475, 에러(err): 0.0334, 승리횟수(Win count): 289, 승리비율(Win ratio): 60.7143
# 반복(Epoch): 476, 에러(err): 0.0117, 승리횟수(Win count): 290, 승리비율(Win ratio): 60.7966
# 반복(Epoch): 477, 에러(err): 0.0121, 승리횟수(Win count): 291, 승리비율(Win ratio): 60.8787
# 반복(Epoch): 478, 에러(err): 0.0085, 승리횟수(Win count): 292, 승리비율(Win ratio): 60.9603
# 반복(Epoch): 479, 에러(err): 0.0268, 승리횟수(Win count): 293, 승리비율(Win ratio): 61.0417
# 반복(Epoch): 480, 에러(err): 0.0237, 승리횟수(Win count): 294, 승리비율(Win ratio): 61.1227
# 반복(Epoch): 481, 에러(err): 0.0362, 승리횟수(Win count): 295, 승리비율(Win ratio): 61.2033
# 반복(Epoch): 482, 에러(err): 0.0122, 승리횟수(Win count): 296, 승리비율(Win ratio): 61.2836
# 반복(Epoch): 483, 에러(err): 0.0264, 승리횟수(Win count): 297, 승리비율(Win ratio): 61.3636
# 반복(Epoch): 484, 에러(err): 0.0113, 승리횟수(Win count): 298, 승리비율(Win ratio): 61.4433
# 반복(Epoch): 485, 에러(err): 0.0091, 승리횟수(Win count): 299, 승리비율(Win ratio): 61.5226
# 반복(Epoch): 486, 에러(err): 0.0083, 승리횟수(Win count): 300, 승리비율(Win ratio): 61.6016
# 반복(Epoch): 487, 에러(err): 0.0218, 승리횟수(Win count): 301, 승리비율(Win ratio): 61.6803
# 반복(Epoch): 488, 에러(err): 0.0087, 승리횟수(Win count): 302, 승리비율(Win ratio): 61.7587
# 반복(Epoch): 489, 에러(err): 0.0128, 승리횟수(Win count): 303, 승리비율(Win ratio): 61.8367
# 반복(Epoch): 490, 에러(err): 0.0067, 승리횟수(Win count): 304, 승리비율(Win ratio): 61.9145
# 반복(Epoch): 491, 에러(err): 0.0089, 승리횟수(Win count): 305, 승리비율(Win ratio): 61.9919
# 반복(Epoch): 492, 에러(err): 0.0479, 승리횟수(Win count): 306, 승리비율(Win ratio): 62.0690
# 반복(Epoch): 493, 에러(err): 0.0161, 승리횟수(Win count): 307, 승리비율(Win ratio): 62.1457
# 반복(Epoch): 494, 에러(err): 0.0153, 승리횟수(Win count): 308, 승리비율(Win ratio): 62.2222
# 반복(Epoch): 495, 에러(err): 0.0168, 승리횟수(Win count): 309, 승리비율(Win ratio): 62.2984
# 반복(Epoch): 496, 에러(err): 0.0201, 승리횟수(Win count): 310, 승리비율(Win ratio): 62.3742
# 반복(Epoch): 497, 에러(err): 0.0252, 승리횟수(Win count): 311, 승리비율(Win ratio): 62.4498
# 반복(Epoch): 498, 에러(err): 0.0252, 승리횟수(Win count): 312, 승리비율(Win ratio): 62.5251
# 반복(Epoch): 499, 에러(err): 0.0246, 승리횟수(Win count): 313, 승리비율(Win ratio): 62.6000
# 반복(Epoch): 500, 에러(err): 0.0650, 승리횟수(Win count): 314, 승리비율(Win ratio): 62.6747
# 반복(Epoch): 501, 에러(err): 0.0278, 승리횟수(Win count): 315, 승리비율(Win ratio): 62.7490
# 반복(Epoch): 502, 에러(err): 0.0560, 승리횟수(Win count): 316, 승리비율(Win ratio): 62.8231
# 반복(Epoch): 503, 에러(err): 0.0167, 승리횟수(Win count): 317, 승리비율(Win ratio): 62.8968
# 반복(Epoch): 504, 에러(err): 0.0148, 승리횟수(Win count): 318, 승리비율(Win ratio): 62.9703
# 반복(Epoch): 505, 에러(err): 0.0331, 승리횟수(Win count): 319, 승리비율(Win ratio): 63.0435
# 반복(Epoch): 506, 에러(err): 0.0440, 승리횟수(Win count): 320, 승리비율(Win ratio): 63.1164
# 반복(Epoch): 507, 에러(err): 0.0129, 승리횟수(Win count): 321, 승리비율(Win ratio): 63.1890
# 반복(Epoch): 508, 에러(err): 0.0486, 승리횟수(Win count): 322, 승리비율(Win ratio): 63.2613
# 반복(Epoch): 509, 에러(err): 0.0368, 승리횟수(Win count): 323, 승리비율(Win ratio): 63.3333
# 반복(Epoch): 510, 에러(err): 0.0130, 승리횟수(Win count): 324, 승리비율(Win ratio): 63.4051
# 반복(Epoch): 511, 에러(err): 0.0228, 승리횟수(Win count): 325, 승리비율(Win ratio): 63.4766
# 반복(Epoch): 512, 에러(err): 0.0255, 승리횟수(Win count): 326, 승리비율(Win ratio): 63.5478
# 반복(Epoch): 513, 에러(err): 0.0244, 승리횟수(Win count): 327, 승리비율(Win ratio): 63.6187
# 반복(Epoch): 514, 에러(err): 0.0176, 승리횟수(Win count): 328, 승리비율(Win ratio): 63.6893
# 반복(Epoch): 515, 에러(err): 0.0198, 승리횟수(Win count): 329, 승리비율(Win ratio): 63.7597
# 반복(Epoch): 516, 에러(err): 0.0162, 승리횟수(Win count): 330, 승리비율(Win ratio): 63.8298
# 반복(Epoch): 517, 에러(err): 0.0126, 승리횟수(Win count): 331, 승리비율(Win ratio): 63.8996
# 반복(Epoch): 518, 에러(err): 0.0217, 승리횟수(Win count): 332, 승리비율(Win ratio): 63.9692
# 반복(Epoch): 519, 에러(err): 0.0170, 승리횟수(Win count): 333, 승리비율(Win ratio): 64.0385
# 반복(Epoch): 520, 에러(err): 0.0105, 승리횟수(Win count): 334, 승리비율(Win ratio): 64.1075
# 반복(Epoch): 521, 에러(err): 0.0068, 승리횟수(Win count): 335, 승리비율(Win ratio): 64.1762
# 반복(Epoch): 522, 에러(err): 0.0132, 승리횟수(Win count): 336, 승리비율(Win ratio): 64.2447
# 반복(Epoch): 523, 에러(err): 0.0128, 승리횟수(Win count): 337, 승리비율(Win ratio): 64.3130
# 반복(Epoch): 524, 에러(err): 0.0122, 승리횟수(Win count): 338, 승리비율(Win ratio): 64.3810
# 반복(Epoch): 525, 에러(err): 0.0092, 승리횟수(Win count): 339, 승리비율(Win ratio): 64.4487
# 반복(Epoch): 526, 에러(err): 0.0116, 승리횟수(Win count): 340, 승리비율(Win ratio): 64.5161
# 반복(Epoch): 527, 에러(err): 0.0337, 승리횟수(Win count): 340, 승리비율(Win ratio): 64.3939
# 반복(Epoch): 528, 에러(err): 0.0104, 승리횟수(Win count): 341, 승리비율(Win ratio): 64.4612
# 반복(Epoch): 529, 에러(err): 0.0251, 승리횟수(Win count): 342, 승리비율(Win ratio): 64.5283
# 반복(Epoch): 530, 에러(err): 0.0184, 승리횟수(Win count): 343, 승리비율(Win ratio): 64.5951
# 반복(Epoch): 531, 에러(err): 0.0164, 승리횟수(Win count): 344, 승리비율(Win ratio): 64.6617
# 반복(Epoch): 532, 에러(err): 0.0278, 승리횟수(Win count): 345, 승리비율(Win ratio): 64.7280
# 반복(Epoch): 533, 에러(err): 0.0195, 승리횟수(Win count): 346, 승리비율(Win ratio): 64.7940
# 반복(Epoch): 534, 에러(err): 0.0181, 승리횟수(Win count): 347, 승리비율(Win ratio): 64.8598
# 반복(Epoch): 535, 에러(err): 0.0108, 승리횟수(Win count): 348, 승리비율(Win ratio): 64.9254
# 반복(Epoch): 536, 에러(err): 0.0075, 승리횟수(Win count): 349, 승리비율(Win ratio): 64.9907
# 반복(Epoch): 537, 에러(err): 0.0091, 승리횟수(Win count): 350, 승리비율(Win ratio): 65.0558
# 반복(Epoch): 538, 에러(err): 0.0138, 승리횟수(Win count): 351, 승리비율(Win ratio): 65.1206
# 반복(Epoch): 539, 에러(err): 0.0072, 승리횟수(Win count): 352, 승리비율(Win ratio): 65.1852
# 반복(Epoch): 540, 에러(err): 0.0152, 승리횟수(Win count): 353, 승리비율(Win ratio): 65.2495
# 반복(Epoch): 541, 에러(err): 0.0145, 승리횟수(Win count): 354, 승리비율(Win ratio): 65.3137
# 반복(Epoch): 542, 에러(err): 0.0146, 승리횟수(Win count): 355, 승리비율(Win ratio): 65.3775
# 반복(Epoch): 543, 에러(err): 0.0110, 승리횟수(Win count): 356, 승리비율(Win ratio): 65.4412
# 반복(Epoch): 544, 에러(err): 0.0063, 승리횟수(Win count): 357, 승리비율(Win ratio): 65.5046
# 반복(Epoch): 545, 에러(err): 0.0050, 승리횟수(Win count): 358, 승리비율(Win ratio): 65.5678
# 반복(Epoch): 546, 에러(err): 0.0054, 승리횟수(Win count): 359, 승리비율(Win ratio): 65.6307
# 반복(Epoch): 547, 에러(err): 0.0041, 승리횟수(Win count): 360, 승리비율(Win ratio): 65.6934
# 반복(Epoch): 548, 에러(err): 0.0056, 승리횟수(Win count): 361, 승리비율(Win ratio): 65.7559
# 반복(Epoch): 549, 에러(err): 0.0065, 승리횟수(Win count): 362, 승리비율(Win ratio): 65.8182
# 반복(Epoch): 550, 에러(err): 0.0079, 승리횟수(Win count): 363, 승리비율(Win ratio): 65.8802
# 반복(Epoch): 551, 에러(err): 0.0085, 승리횟수(Win count): 364, 승리비율(Win ratio): 65.9420
# 반복(Epoch): 552, 에러(err): 0.0034, 승리횟수(Win count): 365, 승리비율(Win ratio): 66.0036
# 반복(Epoch): 553, 에러(err): 0.0042, 승리횟수(Win count): 366, 승리비율(Win ratio): 66.0650
# 반복(Epoch): 554, 에러(err): 0.0041, 승리횟수(Win count): 367, 승리비율(Win ratio): 66.1261
# 반복(Epoch): 555, 에러(err): 0.0034, 승리횟수(Win count): 368, 승리비율(Win ratio): 66.1871
# 반복(Epoch): 556, 에러(err): 0.0049, 승리횟수(Win count): 369, 승리비율(Win ratio): 66.2478
# 반복(Epoch): 557, 에러(err): 0.0038, 승리횟수(Win count): 370, 승리비율(Win ratio): 66.3082
# 반복(Epoch): 558, 에러(err): 0.0044, 승리횟수(Win count): 371, 승리비율(Win ratio): 66.3685
# 반복(Epoch): 559, 에러(err): 0.0036, 승리횟수(Win count): 372, 승리비율(Win ratio): 66.4286
# 반복(Epoch): 560, 에러(err): 0.0032, 승리횟수(Win count): 373, 승리비율(Win ratio): 66.4884
# 반복(Epoch): 561, 에러(err): 0.0027, 승리횟수(Win count): 374, 승리비율(Win ratio): 66.5480
# 반복(Epoch): 562, 에러(err): 0.0034, 승리횟수(Win count): 375, 승리비율(Win ratio): 66.6075
# 반복(Epoch): 563, 에러(err): 0.0043, 승리횟수(Win count): 376, 승리비율(Win ratio): 66.6667
# 반복(Epoch): 564, 에러(err): 0.0024, 승리횟수(Win count): 377, 승리비율(Win ratio): 66.7257
# 반복(Epoch): 565, 에러(err): 0.0039, 승리횟수(Win count): 378, 승리비율(Win ratio): 66.7845
# 반복(Epoch): 566, 에러(err): 0.0044, 승리횟수(Win count): 379, 승리비율(Win ratio): 66.8430
# 반복(Epoch): 567, 에러(err): 0.0034, 승리횟수(Win count): 380, 승리비율(Win ratio): 66.9014
# 반복(Epoch): 568, 에러(err): 0.0043, 승리횟수(Win count): 381, 승리비율(Win ratio): 66.9596
# 반복(Epoch): 569, 에러(err): 0.0029, 승리횟수(Win count): 382, 승리비율(Win ratio): 67.0175
# 반복(Epoch): 570, 에러(err): 0.0030, 승리횟수(Win count): 383, 승리비율(Win ratio): 67.0753
# 반복(Epoch): 571, 에러(err): 0.0026, 승리횟수(Win count): 384, 승리비율(Win ratio): 67.1329
# 반복(Epoch): 572, 에러(err): 0.0016, 승리횟수(Win count): 385, 승리비율(Win ratio): 67.1902
# 반복(Epoch): 573, 에러(err): 0.0028, 승리횟수(Win count): 386, 승리비율(Win ratio): 67.2474
# 반복(Epoch): 574, 에러(err): 0.0027, 승리횟수(Win count): 387, 승리비율(Win ratio): 67.3043
# 반복(Epoch): 575, 에러(err): 0.0020, 승리횟수(Win count): 388, 승리비율(Win ratio): 67.3611
# 반복(Epoch): 576, 에러(err): 0.0036, 승리횟수(Win count): 389, 승리비율(Win ratio): 67.4177
# 반복(Epoch): 577, 에러(err): 0.0025, 승리횟수(Win count): 390, 승리비율(Win ratio): 67.4740
# 반복(Epoch): 578, 에러(err): 0.0038, 승리횟수(Win count): 391, 승리비율(Win ratio): 67.5302
# 반복(Epoch): 579, 에러(err): 0.0027, 승리횟수(Win count): 392, 승리비율(Win ratio): 67.5862
# 반복(Epoch): 580, 에러(err): 0.0016, 승리횟수(Win count): 393, 승리비율(Win ratio): 67.6420
# 반복(Epoch): 581, 에러(err): 0.0019, 승리횟수(Win count): 394, 승리비율(Win ratio): 67.6976
# 반복(Epoch): 582, 에러(err): 0.0019, 승리횟수(Win count): 395, 승리비율(Win ratio): 67.7530
# 반복(Epoch): 583, 에러(err): 0.0014, 승리횟수(Win count): 396, 승리비율(Win ratio): 67.8082
# 반복(Epoch): 584, 에러(err): 0.0022, 승리횟수(Win count): 397, 승리비율(Win ratio): 67.8632
# 반복(Epoch): 585, 에러(err): 0.0024, 승리횟수(Win count): 398, 승리비율(Win ratio): 67.9181
# 반복(Epoch): 586, 에러(err): 0.0023, 승리횟수(Win count): 399, 승리비율(Win ratio): 67.9727
# 반복(Epoch): 587, 에러(err): 0.0026, 승리횟수(Win count): 400, 승리비율(Win ratio): 68.0272
# 반복(Epoch): 588, 에러(err): 0.0019, 승리횟수(Win count): 401, 승리비율(Win ratio): 68.0815
# 반복(Epoch): 589, 에러(err): 0.0012, 승리횟수(Win count): 402, 승리비율(Win ratio): 68.1356
# 반복(Epoch): 590, 에러(err): 0.0013, 승리횟수(Win count): 403, 승리비율(Win ratio): 68.1895
# 반복(Epoch): 591, 에러(err): 0.0013, 승리횟수(Win count): 404, 승리비율(Win ratio): 68.2432
# 반복(Epoch): 592, 에러(err): 0.0011, 승리횟수(Win count): 405, 승리비율(Win ratio): 68.2968
# 반복(Epoch): 593, 에러(err): 0.0012, 승리횟수(Win count): 406, 승리비율(Win ratio): 68.3502
# 반복(Epoch): 594, 에러(err): 0.0016, 승리횟수(Win count): 407, 승리비율(Win ratio): 68.4034
# 반복(Epoch): 595, 에러(err): 0.0017, 승리횟수(Win count): 408, 승리비율(Win ratio): 68.4564
# 반복(Epoch): 596, 에러(err): 0.0013, 승리횟수(Win count): 409, 승리비율(Win ratio): 68.5092
# 반복(Epoch): 597, 에러(err): 0.0010, 승리횟수(Win count): 410, 승리비율(Win ratio): 68.5619
# 반복(Epoch): 598, 에러(err): 0.0013, 승리횟수(Win count): 411, 승리비율(Win ratio): 68.6144
# 반복(Epoch): 599, 에러(err): 0.0016, 승리횟수(Win count): 412, 승리비율(Win ratio): 68.6667
# 반복(Epoch): 600, 에러(err): 0.0012, 승리횟수(Win count): 413, 승리비율(Win ratio): 68.7188
# 반복(Epoch): 601, 에러(err): 0.0014, 승리횟수(Win count): 414, 승리비율(Win ratio): 68.7708
# 반복(Epoch): 602, 에러(err): 0.0011, 승리횟수(Win count): 415, 승리비율(Win ratio): 68.8226
# 반복(Epoch): 603, 에러(err): 0.0014, 승리횟수(Win count): 416, 승리비율(Win ratio): 68.8742
# ...
# 반복(Epoch): 1811, 에러(err): 0.0000, 승리횟수(Win count): 1623, 승리비율(Win ratio): 89.5695
# 반복(Epoch): 1812, 에러(err): 0.0000, 승리횟수(Win count): 1624, 승리비율(Win ratio): 89.5753
# 반복(Epoch): 1813, 에러(err): 0.0000, 승리횟수(Win count): 1625, 승리비율(Win ratio): 89.5810
# 반복(Epoch): 1814, 에러(err): 0.0000, 승리횟수(Win count): 1626, 승리비율(Win ratio): 89.5868
# 반복(Epoch): 1815, 에러(err): 0.0000, 승리횟수(Win count): 1627, 승리비율(Win ratio): 89.5925
# 반복(Epoch): 1816, 에러(err): 0.0000, 승리횟수(Win count): 1628, 승리비율(Win ratio): 89.5982
# 반복(Epoch): 1817, 에러(err): 0.0000, 승리횟수(Win count): 1629, 승리비율(Win ratio): 89.6040
# 반복(Epoch): 1818, 에러(err): 0.0000, 승리횟수(Win count): 1630, 승리비율(Win ratio): 89.6097
# 반복(Epoch): 1819, 에러(err): 0.0000, 승리횟수(Win count): 1631, 승리비율(Win ratio): 89.6154
# 반복(Epoch): 1820, 에러(err): 0.0000, 승리횟수(Win count): 1632, 승리비율(Win ratio): 89.6211
# 반복(Epoch): 1821, 에러(err): 0.0000, 승리횟수(Win count): 1633, 승리비율(Win ratio): 89.6268
# 반복(Epoch): 1822, 에러(err): 0.0000, 승리횟수(Win count): 1634, 승리비율(Win ratio): 89.6325
# 반복(Epoch): 1823, 에러(err): 0.0000, 승리횟수(Win count): 1635, 승리비율(Win ratio): 89.6382
# 반복(Epoch): 1824, 에러(err): 0.0000, 승리횟수(Win count): 1636, 승리비율(Win ratio): 89.6438
# 반복(Epoch): 1825, 에러(err): 0.0000, 승리횟수(Win count): 1637, 승리비율(Win ratio): 89.6495
# 반복(Epoch): 1826, 에러(err): 0.0000, 승리횟수(Win count): 1638, 승리비율(Win ratio): 89.6552
# 반복(Epoch): 1827, 에러(err): 0.0000, 승리횟수(Win count): 1639, 승리비율(Win ratio): 89.6608
# 반복(Epoch): 1828, 에러(err): 0.0000, 승리횟수(Win count): 1640, 승리비율(Win ratio): 89.6665
# 반복(Epoch): 1829, 에러(err): 0.0000, 승리횟수(Win count): 1641, 승리비율(Win ratio): 89.6721
# 반복(Epoch): 1830, 에러(err): 0.0000, 승리횟수(Win count): 1642, 승리비율(Win ratio): 89.6778
# 반복(Epoch): 1831, 에러(err): 0.0000, 승리횟수(Win count): 1643, 승리비율(Win ratio): 89.6834
# 반복(Epoch): 1832, 에러(err): 0.0000, 승리횟수(Win count): 1644, 승리비율(Win ratio): 89.6890
# 반복(Epoch): 1833, 에러(err): 0.0000, 승리횟수(Win count): 1645, 승리비율(Win ratio): 89.6947
# 반복(Epoch): 1834, 에러(err): 0.0000, 승리횟수(Win count): 1646, 승리비율(Win ratio): 89.7003
# 반복(Epoch): 1835, 에러(err): 0.0000, 승리횟수(Win count): 1647, 승리비율(Win ratio): 89.7059
# 반복(Epoch): 1836, 에러(err): 0.0000, 승리횟수(Win count): 1648, 승리비율(Win ratio): 89.7115
# 반복(Epoch): 1837, 에러(err): 0.0000, 승리횟수(Win count): 1649, 승리비율(Win ratio): 89.7171
# 반복(Epoch): 1838, 에러(err): 0.0000, 승리횟수(Win count): 1650, 승리비율(Win ratio): 89.7227
# 반복(Epoch): 1839, 에러(err): 0.0000, 승리횟수(Win count): 1651, 승리비율(Win ratio): 89.7283
# 반복(Epoch): 1840, 에러(err): 0.0000, 승리횟수(Win count): 1652, 승리비율(Win ratio): 89.7338
# 반복(Epoch): 1841, 에러(err): 0.0000, 승리횟수(Win count): 1653, 승리비율(Win ratio): 89.7394
# 반복(Epoch): 1842, 에러(err): 0.0000, 승리횟수(Win count): 1654, 승리비율(Win ratio): 89.7450
# 반복(Epoch): 1843, 에러(err): 0.0000, 승리횟수(Win count): 1655, 승리비율(Win ratio): 89.7505
# 반복(Epoch): 1844, 에러(err): 0.0000, 승리횟수(Win count): 1656, 승리비율(Win ratio): 89.7561
# 반복(Epoch): 1845, 에러(err): 0.0000, 승리횟수(Win count): 1657, 승리비율(Win ratio): 89.7616
# 반복(Epoch): 1846, 에러(err): 0.0000, 승리횟수(Win count): 1658, 승리비율(Win ratio): 89.7672
# 반복(Epoch): 1847, 에러(err): 0.0000, 승리횟수(Win count): 1659, 승리비율(Win ratio): 89.7727
# 반복(Epoch): 1848, 에러(err): 0.0000, 승리횟수(Win count): 1660, 승리비율(Win ratio): 89.7783
# 반복(Epoch): 1849, 에러(err): 0.0000, 승리횟수(Win count): 1661, 승리비율(Win ratio): 89.7838
# 반복(Epoch): 1850, 에러(err): 0.0000, 승리횟수(Win count): 1662, 승리비율(Win ratio): 89.7893
# 반복(Epoch): 1851, 에러(err): 0.0000, 승리횟수(Win count): 1663, 승리비율(Win ratio): 89.7948
# 반복(Epoch): 1852, 에러(err): 0.0000, 승리횟수(Win count): 1664, 승리비율(Win ratio): 89.8003
# 반복(Epoch): 1853, 에러(err): 0.0000, 승리횟수(Win count): 1665, 승리비율(Win ratio): 89.8058
# 반복(Epoch): 1854, 에러(err): 0.0000, 승리횟수(Win count): 1666, 승리비율(Win ratio): 89.8113
# 반복(Epoch): 1855, 에러(err): 0.0000, 승리횟수(Win count): 1667, 승리비율(Win ratio): 89.8168
# 반복(Epoch): 1856, 에러(err): 0.0000, 승리횟수(Win count): 1668, 승리비율(Win ratio): 89.8223
# 반복(Epoch): 1857, 에러(err): 0.0000, 승리횟수(Win count): 1669, 승리비율(Win ratio): 89.8278
# 반복(Epoch): 1858, 에러(err): 0.0000, 승리횟수(Win count): 1670, 승리비율(Win ratio): 89.8332
# 반복(Epoch): 1859, 에러(err): 0.0000, 승리횟수(Win count): 1671, 승리비율(Win ratio): 89.8387
# 반복(Epoch): 1860, 에러(err): 0.0000, 승리횟수(Win count): 1672, 승리비율(Win ratio): 89.8442
# 반복(Epoch): 1861, 에러(err): 0.0000, 승리횟수(Win count): 1673, 승리비율(Win ratio): 89.8496
# 반복(Epoch): 1862, 에러(err): 0.0000, 승리횟수(Win count): 1674, 승리비율(Win ratio): 89.8551
# 반복(Epoch): 1863, 에러(err): 0.0000, 승리횟수(Win count): 1675, 승리비율(Win ratio): 89.8605
# 반복(Epoch): 1864, 에러(err): 0.0000, 승리횟수(Win count): 1676, 승리비율(Win ratio): 89.8660
# 반복(Epoch): 1865, 에러(err): 0.0000, 승리횟수(Win count): 1677, 승리비율(Win ratio): 89.8714
# 반복(Epoch): 1866, 에러(err): 0.0000, 승리횟수(Win count): 1678, 승리비율(Win ratio): 89.8768
# 반복(Epoch): 1867, 에러(err): 0.0000, 승리횟수(Win count): 1679, 승리비율(Win ratio): 89.8822
# 반복(Epoch): 1868, 에러(err): 0.0000, 승리횟수(Win count): 1680, 승리비율(Win ratio): 89.8876
# 반복(Epoch): 1869, 에러(err): 0.0000, 승리횟수(Win count): 1681, 승리비율(Win ratio): 89.8930
# 반복(Epoch): 1870, 에러(err): 0.0000, 승리횟수(Win count): 1682, 승리비율(Win ratio): 89.8985
# 반복(Epoch): 1871, 에러(err): 0.0000, 승리횟수(Win count): 1683, 승리비율(Win ratio): 89.9038
# 반복(Epoch): 1872, 에러(err): 0.0000, 승리횟수(Win count): 1684, 승리비율(Win ratio): 89.9092
# 반복(Epoch): 1873, 에러(err): 0.0000, 승리횟수(Win count): 1685, 승리비율(Win ratio): 89.9146
# 반복(Epoch): 1874, 에러(err): 0.0000, 승리횟수(Win count): 1686, 승리비율(Win ratio): 89.9200
# 반복(Epoch): 1875, 에러(err): 0.0000, 승리횟수(Win count): 1687, 승리비율(Win ratio): 89.9254
# 반복(Epoch): 1876, 에러(err): 0.0000, 승리횟수(Win count): 1688, 승리비율(Win ratio): 89.9307
# 반복(Epoch): 1877, 에러(err): 0.0000, 승리횟수(Win count): 1689, 승리비율(Win ratio): 89.9361
# 반복(Epoch): 1878, 에러(err): 0.0000, 승리횟수(Win count): 1690, 승리비율(Win ratio): 89.9415
# 반복(Epoch): 1879, 에러(err): 0.0000, 승리횟수(Win count): 1691, 승리비율(Win ratio): 89.9468
# 반복(Epoch): 1880, 에러(err): 0.0000, 승리횟수(Win count): 1692, 승리비율(Win ratio): 89.9522
# 반복(Epoch): 1881, 에러(err): 0.0000, 승리횟수(Win count): 1693, 승리비율(Win ratio): 89.9575
# 반복(Epoch): 1882, 에러(err): 0.0000, 승리횟수(Win count): 1694, 승리비율(Win ratio): 89.9628
# 반복(Epoch): 1883, 에러(err): 0.0000, 승리횟수(Win count): 1695, 승리비율(Win ratio): 89.9682
# 반복(Epoch): 1884, 에러(err): 0.0000, 승리횟수(Win count): 1696, 승리비율(Win ratio): 89.9735
# 반복(Epoch): 1885, 에러(err): 0.0000, 승리횟수(Win count): 1697, 승리비율(Win ratio): 89.9788
# 반복(Epoch): 1886, 에러(err): 0.0000, 승리횟수(Win count): 1698, 승리비율(Win ratio): 89.9841
# 반복(Epoch): 1887, 에러(err): 0.0000, 승리횟수(Win count): 1699, 승리비율(Win ratio): 89.9894
# 반복(Epoch): 1888, 에러(err): 0.0000, 승리횟수(Win count): 1700, 승리비율(Win ratio): 89.9947
# 반복(Epoch): 1889, 에러(err): 0.0000, 승리횟수(Win count): 1701, 승리비율(Win ratio): 90.0000
# 반복(Epoch): 1890, 에러(err): 0.0000, 승리횟수(Win count): 1702, 승리비율(Win ratio): 90.0053
# 반복(Epoch): 1891, 에러(err): 0.0000, 승리횟수(Win count): 1703, 승리비율(Win ratio): 90.0106
# 반복(Epoch): 1892, 에러(err): 0.0000, 승리횟수(Win count): 1704, 승리비율(Win ratio): 90.0158
# 반복(Epoch): 1893, 에러(err): 0.0001, 승리횟수(Win count): 1705, 승리비율(Win ratio): 90.0211
# 반복(Epoch): 1894, 에러(err): 0.0002, 승리횟수(Win count): 1706, 승리비율(Win ratio): 90.0264
# 반복(Epoch): 1895, 에러(err): 0.0000, 승리횟수(Win count): 1707, 승리비율(Win ratio): 90.0316
# 반복(Epoch): 1896, 에러(err): 0.0001, 승리횟수(Win count): 1708, 승리비율(Win ratio): 90.0369
# 반복(Epoch): 1897, 에러(err): 0.0000, 승리횟수(Win count): 1709, 승리비율(Win ratio): 90.0421
# 반복(Epoch): 1898, 에러(err): 0.0000, 승리횟수(Win count): 1710, 승리비율(Win ratio): 90.0474
# 반복(Epoch): 1899, 에러(err): 0.0001, 승리횟수(Win count): 1711, 승리비율(Win ratio): 90.0526
# 반복(Epoch): 1900, 에러(err): 0.0000, 승리횟수(Win count): 1712, 승리비율(Win ratio): 90.0579
# 반복(Epoch): 1901, 에러(err): 0.0001, 승리횟수(Win count): 1713, 승리비율(Win ratio): 90.0631
# 반복(Epoch): 1902, 에러(err): 0.0000, 승리횟수(Win count): 1714, 승리비율(Win ratio): 90.0683
# 반복(Epoch): 1903, 에러(err): 0.0000, 승리횟수(Win count): 1715, 승리비율(Win ratio): 90.0735
# 반복(Epoch): 1904, 에러(err): 0.0000, 승리횟수(Win count): 1716, 승리비율(Win ratio): 90.0787
# 반복(Epoch): 1905, 에러(err): 0.0000, 승리횟수(Win count): 1717, 승리비율(Win ratio): 90.0839
# 반복(Epoch): 1906, 에러(err): 0.0000, 승리횟수(Win count): 1718, 승리비율(Win ratio): 90.0891
# 반복(Epoch): 1907, 에러(err): 0.0000, 승리횟수(Win count): 1719, 승리비율(Win ratio): 90.0943
# 반복(Epoch): 1908, 에러(err): 0.0001, 승리횟수(Win count): 1720, 승리비율(Win ratio): 90.0995
# 반복(Epoch): 1909, 에러(err): 0.0000, 승리횟수(Win count): 1721, 승리비율(Win ratio): 90.1047
# 반복(Epoch): 1910, 에러(err): 0.0000, 승리횟수(Win count): 1722, 승리비율(Win ratio): 90.1099
# 반복(Epoch): 1911, 에러(err): 0.0000, 승리횟수(Win count): 1723, 승리비율(Win ratio): 90.1151
# 반복(Epoch): 1912, 에러(err): 0.0000, 승리횟수(Win count): 1724, 승리비율(Win ratio): 90.1202
# 반복(Epoch): 1913, 에러(err): 0.0000, 승리횟수(Win count): 1725, 승리비율(Win ratio): 90.1254
# 반복(Epoch): 1914, 에러(err): 0.0000, 승리횟수(Win count): 1726, 승리비율(Win ratio): 90.1305
# 반복(Epoch): 1915, 에러(err): 0.0000, 승리횟수(Win count): 1727, 승리비율(Win ratio): 90.1357
# 반복(Epoch): 1916, 에러(err): 0.0000, 승리횟수(Win count): 1728, 승리비율(Win ratio): 90.1408
# 반복(Epoch): 1917, 에러(err): 0.0000, 승리횟수(Win count): 1729, 승리비율(Win ratio): 90.1460
# 반복(Epoch): 1918, 에러(err): 0.0000, 승리횟수(Win count): 1730, 승리비율(Win ratio): 90.1511
# 반복(Epoch): 1919, 에러(err): 0.0000, 승리횟수(Win count): 1731, 승리비율(Win ratio): 90.1562
# 반복(Epoch): 1920, 에러(err): 0.0000, 승리횟수(Win count): 1732, 승리비율(Win ratio): 90.1614
# 반복(Epoch): 1921, 에러(err): 0.0000, 승리횟수(Win count): 1733, 승리비율(Win ratio): 90.1665
# 반복(Epoch): 1922, 에러(err): 0.0000, 승리횟수(Win count): 1734, 승리비율(Win ratio): 90.1716
# 반복(Epoch): 1923, 에러(err): 0.0000, 승리횟수(Win count): 1735, 승리비율(Win ratio): 90.1767
# 반복(Epoch): 1924, 에러(err): 0.0000, 승리횟수(Win count): 1736, 승리비율(Win ratio): 90.1818
# 반복(Epoch): 1925, 에러(err): 0.0001, 승리횟수(Win count): 1737, 승리비율(Win ratio): 90.1869
# 반복(Epoch): 1926, 에러(err): 0.0000, 승리횟수(Win count): 1738, 승리비율(Win ratio): 90.1920
# 반복(Epoch): 1927, 에러(err): 0.0000, 승리횟수(Win count): 1739, 승리비율(Win ratio): 90.1971
# 반복(Epoch): 1928, 에러(err): 0.0000, 승리횟수(Win count): 1740, 승리비율(Win ratio): 90.2022
# 반복(Epoch): 1929, 에러(err): 0.0008, 승리횟수(Win count): 1741, 승리비율(Win ratio): 90.2073
# 반복(Epoch): 1930, 에러(err): 0.0001, 승리횟수(Win count): 1742, 승리비율(Win ratio): 90.2123
# 반복(Epoch): 1931, 에러(err): 0.0004, 승리횟수(Win count): 1743, 승리비율(Win ratio): 90.2174
# 반복(Epoch): 1932, 에러(err): 0.0010, 승리횟수(Win count): 1744, 승리비율(Win ratio): 90.2225
# 반복(Epoch): 1933, 에러(err): 0.0001, 승리횟수(Win count): 1745, 승리비율(Win ratio): 90.2275
# 반복(Epoch): 1934, 에러(err): 0.0004, 승리횟수(Win count): 1746, 승리비율(Win ratio): 90.2326
# 반복(Epoch): 1935, 에러(err): 0.0003, 승리횟수(Win count): 1747, 승리비율(Win ratio): 90.2376
# 반복(Epoch): 1936, 에러(err): 0.0003, 승리횟수(Win count): 1748, 승리비율(Win ratio): 90.2426
# 반복(Epoch): 1937, 에러(err): 0.0003, 승리횟수(Win count): 1749, 승리비율(Win ratio): 90.2477
# 반복(Epoch): 1938, 에러(err): 0.0001, 승리횟수(Win count): 1750, 승리비율(Win ratio): 90.2527
# 반복(Epoch): 1939, 에러(err): 0.0005, 승리횟수(Win count): 1751, 승리비율(Win ratio): 90.2577
# 반복(Epoch): 1940, 에러(err): 0.0001, 승리횟수(Win count): 1752, 승리비율(Win ratio): 90.2628
# 반복(Epoch): 1941, 에러(err): 0.0000, 승리횟수(Win count): 1753, 승리비율(Win ratio): 90.2678
# 반복(Epoch): 1942, 에러(err): 0.0003, 승리횟수(Win count): 1754, 승리비율(Win ratio): 90.2728
# 반복(Epoch): 1943, 에러(err): 0.0001, 승리횟수(Win count): 1755, 승리비율(Win ratio): 90.2778
# 반복(Epoch): 1944, 에러(err): 0.0000, 승리횟수(Win count): 1756, 승리비율(Win ratio): 90.2828
# 반복(Epoch): 1945, 에러(err): 0.0000, 승리횟수(Win count): 1757, 승리비율(Win ratio): 90.2878
# 반복(Epoch): 1946, 에러(err): 0.0005, 승리횟수(Win count): 1758, 승리비율(Win ratio): 90.2928
# 반복(Epoch): 1947, 에러(err): 0.0003, 승리횟수(Win count): 1759, 승리비율(Win ratio): 90.2977
# 반복(Epoch): 1948, 에러(err): 0.0002, 승리횟수(Win count): 1760, 승리비율(Win ratio): 90.3027
# 반복(Epoch): 1949, 에러(err): 0.0002, 승리횟수(Win count): 1761, 승리비율(Win ratio): 90.3077
# 반복(Epoch): 1950, 에러(err): 0.0001, 승리횟수(Win count): 1762, 승리비율(Win ratio): 90.3127
# 반복(Epoch): 1951, 에러(err): 0.0000, 승리횟수(Win count): 1763, 승리비율(Win ratio): 90.3176
# 반복(Epoch): 1952, 에러(err): 0.0003, 승리횟수(Win count): 1764, 승리비율(Win ratio): 90.3226
# 반복(Epoch): 1953, 에러(err): 0.0003, 승리횟수(Win count): 1765, 승리비율(Win ratio): 90.3275
# 반복(Epoch): 1954, 에러(err): 0.0002, 승리횟수(Win count): 1766, 승리비율(Win ratio): 90.3325
# 반복(Epoch): 1955, 에러(err): 0.0000, 승리횟수(Win count): 1767, 승리비율(Win ratio): 90.3374
# 반복(Epoch): 1956, 에러(err): 0.0002, 승리횟수(Win count): 1768, 승리비율(Win ratio): 90.3424
# 반복(Epoch): 1957, 에러(err): 0.0000, 승리횟수(Win count): 1769, 승리비율(Win ratio): 90.3473
# 반복(Epoch): 1958, 에러(err): 0.0002, 승리횟수(Win count): 1770, 승리비율(Win ratio): 90.3522
# 반복(Epoch): 1959, 에러(err): 0.0001, 승리횟수(Win count): 1771, 승리비율(Win ratio): 90.3571
# 반복(Epoch): 1960, 에러(err): 0.0002, 승리횟수(Win count): 1772, 승리비율(Win ratio): 90.3621
# 반복(Epoch): 1961, 에러(err): 0.0002, 승리횟수(Win count): 1773, 승리비율(Win ratio): 90.3670
# 반복(Epoch): 1962, 에러(err): 0.0000, 승리횟수(Win count): 1774, 승리비율(Win ratio): 90.3719
# 반복(Epoch): 1963, 에러(err): 0.0000, 승리횟수(Win count): 1775, 승리비율(Win ratio): 90.3768
# 반복(Epoch): 1964, 에러(err): 0.0000, 승리횟수(Win count): 1776, 승리비율(Win ratio): 90.3817
# 반복(Epoch): 1965, 에러(err): 0.0000, 승리횟수(Win count): 1777, 승리비율(Win ratio): 90.3866
# 반복(Epoch): 1966, 에러(err): 0.0000, 승리횟수(Win count): 1778, 승리비율(Win ratio): 90.3915
# 반복(Epoch): 1967, 에러(err): 0.0000, 승리횟수(Win count): 1779, 승리비율(Win ratio): 90.3963
# 반복(Epoch): 1968, 에러(err): 0.0000, 승리횟수(Win count): 1780, 승리비율(Win ratio): 90.4012
# 반복(Epoch): 1969, 에러(err): 0.0000, 승리횟수(Win count): 1781, 승리비율(Win ratio): 90.4061
# 반복(Epoch): 1970, 에러(err): 0.0002, 승리횟수(Win count): 1782, 승리비율(Win ratio): 90.4110
# 반복(Epoch): 1971, 에러(err): 0.0000, 승리횟수(Win count): 1783, 승리비율(Win ratio): 90.4158
# 반복(Epoch): 1972, 에러(err): 0.0001, 승리횟수(Win count): 1784, 승리비율(Win ratio): 90.4207
# 반복(Epoch): 1973, 에러(err): 0.0000, 승리횟수(Win count): 1785, 승리비율(Win ratio): 90.4255
# 반복(Epoch): 1974, 에러(err): 0.0001, 승리횟수(Win count): 1786, 승리비율(Win ratio): 90.4304
# 반복(Epoch): 1975, 에러(err): 0.0000, 승리횟수(Win count): 1787, 승리비율(Win ratio): 90.4352
# 반복(Epoch): 1976, 에러(err): 0.0001, 승리횟수(Win count): 1788, 승리비율(Win ratio): 90.4401
# 반복(Epoch): 1977, 에러(err): 0.0000, 승리횟수(Win count): 1789, 승리비율(Win ratio): 90.4449
# 반복(Epoch): 1978, 에러(err): 0.0001, 승리횟수(Win count): 1790, 승리비율(Win ratio): 90.4497
# 반복(Epoch): 1979, 에러(err): 0.0000, 승리횟수(Win count): 1791, 승리비율(Win ratio): 90.4545
# 반복(Epoch): 1980, 에러(err): 0.0000, 승리횟수(Win count): 1792, 승리비율(Win ratio): 90.4594
# 반복(Epoch): 1981, 에러(err): 0.0000, 승리횟수(Win count): 1793, 승리비율(Win ratio): 90.4642
# 반복(Epoch): 1982, 에러(err): 0.0001, 승리횟수(Win count): 1794, 승리비율(Win ratio): 90.4690
# 반복(Epoch): 1983, 에러(err): 0.0000, 승리횟수(Win count): 1795, 승리비율(Win ratio): 90.4738
# 반복(Epoch): 1984, 에러(err): 0.0001, 승리횟수(Win count): 1796, 승리비율(Win ratio): 90.4786
# 반복(Epoch): 1985, 에러(err): 0.0001, 승리횟수(Win count): 1797, 승리비율(Win ratio): 90.4834
# 반복(Epoch): 1986, 에러(err): 0.0001, 승리횟수(Win count): 1798, 승리비율(Win ratio): 90.4882
# 반복(Epoch): 1987, 에러(err): 0.0000, 승리횟수(Win count): 1799, 승리비율(Win ratio): 90.4930
# 반복(Epoch): 1988, 에러(err): 0.0001, 승리횟수(Win count): 1800, 승리비율(Win ratio): 90.4977
# 반복(Epoch): 1989, 에러(err): 0.0000, 승리횟수(Win count): 1801, 승리비율(Win ratio): 90.5025
# 반복(Epoch): 1990, 에러(err): 0.0001, 승리횟수(Win count): 1802, 승리비율(Win ratio): 90.5073
# 반복(Epoch): 1991, 에러(err): 0.0000, 승리횟수(Win count): 1803, 승리비율(Win ratio): 90.5120
# 반복(Epoch): 1992, 에러(err): 0.0000, 승리횟수(Win count): 1804, 승리비율(Win ratio): 90.5168
# 반복(Epoch): 1993, 에러(err): 0.0000, 승리횟수(Win count): 1805, 승리비율(Win ratio): 90.5216
# 반복(Epoch): 1994, 에러(err): 0.0000, 승리횟수(Win count): 1806, 승리비율(Win ratio): 90.5263
# 반복(Epoch): 1995, 에러(err): 0.0000, 승리횟수(Win count): 1807, 승리비율(Win ratio): 90.5311
# 반복(Epoch): 1996, 에러(err): 0.0000, 승리횟수(Win count): 1808, 승리비율(Win ratio): 90.5358
# 반복(Epoch): 1997, 에러(err): 0.0000, 승리횟수(Win count): 1809, 승리비율(Win ratio): 90.5405
# 반복(Epoch): 1998, 에러(err): 0.0000, 승리횟수(Win count): 1810, 승리비율(Win ratio): 90.5453
# 반복(Epoch): 1999, 에러(err): 0.0000, 승리횟수(Win count): 1811, 승리비율(Win ratio): 90.5500
# 반복(Epoch): 2000, 에러(err): 0.0000, 승리횟수(Win count): 1812, 승리비율(Win ratio): 90.5547
# 트레이닝 완료
# C:\Users\pnu\Desktop\종합정리\Data-arrangement\강화학습/model.ckpt 경로에 파라미터가 저장되었습니다
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\pnu\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
